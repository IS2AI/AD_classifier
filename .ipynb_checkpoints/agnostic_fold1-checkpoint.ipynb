# %%
import sys
import torch
import torch.nn as nn
from torch import cuda
from torch.autograd import Variable
from torch.utils.data import DataLoader,Dataset

import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils
from PIL import Image

import torch.nn.functional as F

import matplotlib.pyplot as plt
import numpy as np
import random
import torch.optim as optim 

import nibabel as nib
import os
from skimage.transform import resize 
import random
import torch.utils.model_zoo as model_zoo
import torch.nn as nn
import math
import pandas as pd

# %%
class AD_2DSlicesData(Dataset):
    """labeled Faces in the Wild dataset."""
    
    def __init__(self, root_dir_1, root_dir_2, root_dir_3, data_file, transform=None, slice = slice):
        """
        Args:
            root_dir (string): Directory of all the images.
            data_file (string): File name of the train/test split file.
            transform (callable, optional): Optional transform to be applied on a sample.
            data_augmentation (boolean): Optional data augmentation.
        """
        self.root_dir_1 = root_dir_1
        self.root_dir_2 = root_dir_2
        self.root_dir_3 = root_dir_3
        self.data_file = data_file
        self.transform = transform
    
    def __len__(self):
        return sum(1 for line in open(self.data_file))
    
    def __getitem__(self, idx):
        df = open(self.data_file)
        lines = df.readlines()
        lst = lines[idx].split()
        num_images=len(lst)-1
        if num_images == 3:
            img_name_1 = lst[0]
            img_name_2 = lst[1]
            img_name_3 = lst[2]
            img_label = lst[3]
            image_path1 = os.path.join(self.root_dir_1, img_name_1)
            image_path2 = os.path.join(self.root_dir_2, img_name_2)
            image_path3 = os.path.join(self.root_dir_3, img_name_3)
            image1 = Image.open(image_path1)
            image2 = Image.open(image_path2)
            image3 = Image.open(image_path3)

           
        elif num_images == 2:
            img_name_1 = lst[0]
            img_name_2 = lst[1]
            img_label = lst[2]
            image_path1 = os.path.join(self.root_dir_1, img_name_1)
            image_path2 = os.path.join(self.root_dir_2, img_name_2)
            image1 = Image.open(image_path1)         
            image2 = Image.open(image_path2)
            image3 = Image.new("RGB", (224, 224), (255, 255, 255))

          
        elif num_images == 1:
            img_name = lst[0]
            img_label = lst[1]
            if img_name[0]=='r':
                image_path = os.path.join(self.root_dir_3, img_name)
                image1 = Image.new("RGB", (224, 224), (255, 255, 255))
                image2 = Image.new("RGB", (224, 224), (255, 255, 255))
                image3 = Image.open(image_path)         

            elif img_name[0]=='F':
                image_path = os.path.join(self.root_dir_1, img_name)
                image1 =  Image.open(image_path)       
                image2 = Image.new("RGB", (224, 224), (255, 255, 255))
                image3 =Image.new("RGB", (224, 224), (255, 255, 255))
            elif img_name[0]=='M':
                image_path = os.path.join(self.root_dir_2, img_name)
                image1 = Image.new("RGB", (224, 224), (255, 255, 255))    
                image2 = Image.open(image_path) 
                image3 = Image.new("RGB", (224, 224), (255, 255, 255))
                    
                
                
        if img_label == 'Normal':
            label = 0
        elif img_label == 'AD':
            label = 2
        elif img_label == 'MCI':
            label = 1
            #image = Image.fromarray(image.astype(np.uint8), 'RGB')
        if self.transform:
            image1 = self.transform(image1)
            image2 = self.transform(image2)
            image3 = self.transform(image3)

        
        sample = {'t1w': image3,'FA':image1, 'MD':image2, 'label': label}
        return sample

# %%
# Path configuration
TRAINING_PATH = '/home/aidana_massalimova/classifier/agnostic/train_fold1.txt'
TESTING_PATH = '/home/aidana_massalimova/classifier/MD_only/test_fold1_upd.txt'
IMG_PATH_1 = '/home/aidana_massalimova/classifier/agnostic/fold1/train/FA'
IMG_PATH_2 = '/home/aidana_massalimova/classifier/agnostic/fold1/train/MD'
IMG_PATH_3 = '/home/aidana_massalimova/classifier/agnostic/fold1/train/T1w'

IMG_PATH_4 = '/home/aidana_massalimova/classifier/agnostic/fold1/test/FA'
IMG_PATH_5 = '/home/aidana_massalimova/classifier/agnostic/fold1/test/MD'
IMG_PATH_6 = '/home/aidana_massalimova/classifier/agnostic/fold1/test/T1w'


batch_size=16
epochs=200
lr = 1e-3


transforms_train = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
])

transforms_test = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
])
dset_train = AD_2DSlicesData(IMG_PATH_1, IMG_PATH_2,IMG_PATH_3,TRAINING_PATH, transforms_train)
dset_test = AD_2DSlicesData(IMG_PATH_4, IMG_PATH_5,IMG_PATH_6, TESTING_PATH, transforms_test)


# Use argument load to distinguish training and testing
train_loader = DataLoader(dset_train,
                          batch_size = batch_size,
                          shuffle = True,
                          num_workers = 4,
                          drop_last = True
                         )

test_loader = DataLoader(dset_test,
                         batch_size = batch_size,
                         shuffle = False,
                         num_workers = 4,
                         drop_last=True
                         )

# %%
class ResNet18(nn.Module):

    def __init__(self, out_size):
        super(ResNet18, self).__init__()
        self.resnet18 = torchvision.models.resnet18(pretrained=True)
        num_ftrs = self.resnet18.fc.in_features
        self.resnet18.fc = nn.Sequential(
            nn.Linear(num_ftrs, out_size)
        )

    def forward(self, x):
        x = self.resnet18(x)
        return x
    
class MyEnsemble(nn.Module):
    def __init__(self, modelA, modelB,modelC, nb_classes=3):
        super(MyEnsemble, self).__init__()
        self.modelA = modelA
        self.modelB = modelB
        self.modelC = modelC
        # Remove last linear layer
        self.modelA.module.resnet18.fc = nn.Identity()
        self.modelB.module.resnet18.fc = nn.Identity()
        self.modelC.module.resnet18.fc = nn.Identity()
        # Create new classifier
        self.classifier = nn.Linear(512+512+512, nb_classes)
        
    def forward(self, x1,x2,x3):
        x1 = self.modelA(x1) 
        x2 = self.modelB(x2)
        x3 = self.modelC(x3)
        x = torch.cat((x1, x2, x3), dim=1)   
        x = self.classifier(F.relu(x))
        return x

# Train your separate models
                                                

modelA = ResNet18(out_size=3)
modelB = ResNet18(out_size=3)
modelC = ResNet18(out_size=3)


optimizerA = eval("optim.Adam")(modelA.parameters(), 1e-4)      
optimizerB = eval("optim.Adam")(modelB.parameters(), 1e-4)
optimizerC = eval("optim.Adam")(modelC.parameters(), 1e-4)      

# Freeze these models
for param in modelA.parameters():
    param.requires_grad = False

for param in modelB.parameters():
    param.requires_grad = False

    
for param in modelC.parameters():
    param.requires_grad = False
    
gpu_ids=[11]
cuda='cuda:'+str(gpu_ids[0]) 
device=torch.device(cuda)
#cuda='cuda:0'
modelA = nn.DataParallel(modelA, device_ids=gpu_ids)
modelB = nn.DataParallel(modelB, device_ids=gpu_ids)
modelC = nn.DataParallel(modelC, device_ids=gpu_ids)


modelA.to(device)    
modelB.to(device)    
modelC.to(device)    

checkpointA = torch.load('/home/aidana_massalimova/classifier/t1w_only/model1_upd.pt')
modelA.load_state_dict(checkpointA['model_state_dict'])
optimizerA.load_state_dict(checkpointA['optimizer_state_dict'])

checkpointB = torch.load('/home/aidana_massalimova/classifier/FA_only/model1_upd.pt')
modelB.load_state_dict(checkpointB['model_state_dict'])
optimizerB.load_state_dict(checkpointB['optimizer_state_dict'])

checkpointC = torch.load('/home/aidana_massalimova/classifier/MD_only/model1_upd.pt')
modelC.load_state_dict(checkpointC['model_state_dict'])
optimizerC.load_state_dict(checkpointC['optimizer_state_dict'])
                
# Create ensemble model
model = MyEnsemble(modelA, modelB, modelC)
model = nn.DataParallel(model, device_ids=gpu_ids)
model.to(device)    
criterion = torch.nn.CrossEntropyLoss()
optimizer = eval("optim.Adam")(model.parameters(), lr)

# %%
# Training process

last_dev_avg_loss = float("inf")
best_accuracy = float("-inf")
# main training loop
best_accuracy=0
for epoch_i in range(epochs):
    print("At {0}-th epoch.".format(epoch_i))
    train_loss = 0.0
    correct_cnt = 0.0
    model.train()
    for it, train_data in enumerate(train_loader):
        t1w,FA,MD, labels = Variable(train_data['t1w']).to(device), Variable(train_data['FA']).to(device),Variable(train_data['MD']).to(device),Variable(train_data['label']).to(device) 
        integer_encoded = labels.data.cpu().numpy()
        ground_truth = Variable(torch.from_numpy(integer_encoded)).long().to(device)
        train_output = model(t1w,FA,MD)
        train_prob_predict = F.softmax(train_output, dim=1)
        _, predict = train_prob_predict.topk(1)
        loss = criterion(train_output, ground_truth)

        train_loss += loss
        correct_this_batch = (predict.squeeze(1) == ground_truth).sum()
        correct_cnt += correct_this_batch
        accuracy = float(correct_this_batch) / len(ground_truth)
        print("batch {0} training loss is : {1:.5f}".format(it, loss.data))
        print("batch {0} training accuracy is : {1:.5f}".format(it, accuracy))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    train_avg_loss = train_loss / (len(dset_train) / batch_size)
    train_avg_acu = float(correct_cnt) / len(dset_train)
    print("Average training loss is {0:.5f} at the end of epoch {1}".format(train_avg_loss.data, epoch_i))
    print("Average training accuracy is {0:.5f} at the end of epoch {1}".format(train_avg_acu, epoch_i))
    

    # validation -- this is a crude esitmation because there might be some paddings at the end
    dev_loss = 0.0
    correct_cnt = 0.0
    model.eval()
    for it, test_data in enumerate(test_loader):
        with torch.no_grad():
            t1w,FA,MD, labels = Variable(test_data['t1w']).to(device),Variable(test_data['FA']).to(device),Variable(test_data['MD']).to(device), Variable(test_data['label']).to(device) 
            integer_encoded = labels.data.cpu().numpy()
            ground_truth = Variable(torch.from_numpy(integer_encoded)).long().to(device)
    
        test_output = model( t1w,FA,MD)
        test_prob_predict = F.softmax(test_output, dim=1)
        _, predict = test_prob_predict.topk(1)
        loss = criterion(test_output, ground_truth)
        dev_loss += loss
        correct_this_batch = (predict.squeeze(1) == ground_truth).sum()
        correct_cnt += (predict.squeeze(1) == ground_truth).sum()
        accuracy = float(correct_this_batch) / len(ground_truth)
        print("batch {0} dev loss is : {1:.5f}".format(it, loss.data))
        print("batch {0} dev accuracy is : {1:.5f}".format(it, accuracy))

    dev_avg_loss = dev_loss / (len(dset_test) / batch_size)
    dev_avg_acu = float(correct_cnt) / len(dset_test)
    
    print("Average validation loss is {0:.5f} at the end of epoch {1}".format(dev_avg_loss.data, epoch_i))
    print("Average validation accuracy is {0:.5f} at the end of epoch {1}".format(dev_avg_acu, epoch_i))
    if dev_avg_acu>best_accuracy: 
        best_accuracy=dev_avg_acu
        torch.save({ 'epoch': epoch_i,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss}, '/home/aidana_massalimova/classifier/agnostic/model1_upd.pt') # official recommended

    last_dev_avg_loss = dev_avg_loss
# Out:
# At 0-th epoch.
# batch 0 training loss is : 0.98042
# batch 0 training accuracy is : 0.37500
# batch 1 training loss is : 0.76296
# batch 1 training accuracy is : 0.56250
# batch 2 training loss is : 0.49623
# batch 2 training accuracy is : 0.87500
# batch 3 training loss is : 0.47038
# batch 3 training accuracy is : 0.81250
# batch 4 training loss is : 0.18334
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.67062
# batch 5 training accuracy is : 0.62500
# batch 6 training loss is : 0.34389
# batch 6 training accuracy is : 0.87500
# batch 7 training loss is : 0.16025
# batch 7 training accuracy is : 0.93750
# batch 8 training loss is : 0.15005
# batch 8 training accuracy is : 0.93750
# batch 9 training loss is : 0.31900
# batch 9 training accuracy is : 0.87500
# batch 10 training loss is : 0.14230
# batch 10 training accuracy is : 0.93750
# batch 11 training loss is : 0.33573
# batch 11 training accuracy is : 0.87500
# batch 12 training loss is : 0.28799
# batch 12 training accuracy is : 0.87500
# batch 13 training loss is : 0.17462
# batch 13 training accuracy is : 0.93750
# batch 14 training loss is : 0.39866
# batch 14 training accuracy is : 0.81250
# batch 15 training loss is : 0.18633
# batch 15 training accuracy is : 0.87500
# batch 16 training loss is : 0.22593
# batch 16 training accuracy is : 0.81250
# batch 17 training loss is : 0.28580
# batch 17 training accuracy is : 0.93750
# batch 18 training loss is : 0.06444
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.09338
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.08700
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.37086
# batch 21 training accuracy is : 0.75000
# batch 22 training loss is : 0.09016
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.11169
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.19130
# batch 24 training accuracy is : 0.87500
# batch 25 training loss is : 0.29194
# batch 25 training accuracy is : 0.81250
# batch 26 training loss is : 0.19020
# batch 26 training accuracy is : 0.87500
# batch 27 training loss is : 0.30926
# batch 27 training accuracy is : 0.93750
# batch 28 training loss is : 0.16452
# batch 28 training accuracy is : 0.87500
# batch 29 training loss is : 0.14766
# batch 29 training accuracy is : 0.93750
# batch 30 training loss is : 0.05684
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.07466
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.26971
# batch 32 training accuracy is : 0.87500
# batch 33 training loss is : 0.09743
# batch 33 training accuracy is : 0.93750
# batch 34 training loss is : 0.44513
# batch 34 training accuracy is : 0.81250
# batch 35 training loss is : 0.19348
# batch 35 training accuracy is : 0.93750
# batch 36 training loss is : 0.25363
# batch 36 training accuracy is : 0.87500
# batch 37 training loss is : 0.02623
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.12966
# batch 38 training accuracy is : 0.93750
# batch 39 training loss is : 0.29951
# batch 39 training accuracy is : 0.87500
# batch 40 training loss is : 0.12225
# batch 40 training accuracy is : 0.93750
# batch 41 training loss is : 0.10875
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.09577
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.01389
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.19495
# batch 44 training accuracy is : 0.87500
# batch 45 training loss is : 0.21935
# batch 45 training accuracy is : 0.93750
# batch 46 training loss is : 0.07558
# batch 46 training accuracy is : 0.93750
# batch 47 training loss is : 0.10488
# batch 47 training accuracy is : 0.93750
# batch 48 training loss is : 0.13420
# batch 48 training accuracy is : 0.93750
# batch 49 training loss is : 0.03296
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.25609
# batch 50 training accuracy is : 0.81250
# batch 51 training loss is : 0.22689
# batch 51 training accuracy is : 0.81250
# batch 52 training loss is : 0.25308
# batch 52 training accuracy is : 0.81250
# batch 53 training loss is : 0.07550
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00900
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.09874
# batch 55 training accuracy is : 0.93750
# batch 56 training loss is : 0.22264
# batch 56 training accuracy is : 0.93750
# batch 57 training loss is : 0.27718
# batch 57 training accuracy is : 0.93750
# batch 58 training loss is : 0.32816
# batch 58 training accuracy is : 0.87500
# batch 59 training loss is : 0.27932
# batch 59 training accuracy is : 0.87500
# batch 60 training loss is : 0.27784
# batch 60 training accuracy is : 0.87500
# batch 61 training loss is : 0.13656
# batch 61 training accuracy is : 1.00000
# batch 62 training loss is : 0.40259
# batch 62 training accuracy is : 0.81250
# batch 63 training loss is : 0.28057
# batch 63 training accuracy is : 0.87500
# batch 64 training loss is : 0.27727
# batch 64 training accuracy is : 0.87500
# batch 65 training loss is : 0.44500
# batch 65 training accuracy is : 0.75000
# batch 66 training loss is : 0.48321
# batch 66 training accuracy is : 0.75000
# batch 67 training loss is : 0.27886
# batch 67 training accuracy is : 0.93750
# batch 68 training loss is : 0.01885
# batch 68 training accuracy is : 1.00000
# batch 69 training loss is : 0.27354
# batch 69 training accuracy is : 0.75000
# batch 70 training loss is : 0.24580
# batch 70 training accuracy is : 0.87500
# batch 71 training loss is : 0.17287
# batch 71 training accuracy is : 0.87500
# batch 72 training loss is : 0.19028
# batch 72 training accuracy is : 0.87500
# batch 73 training loss is : 0.25649
# batch 73 training accuracy is : 0.87500
# batch 74 training loss is : 0.16541
# batch 74 training accuracy is : 0.93750
# batch 75 training loss is : 0.10171
# batch 75 training accuracy is : 1.00000
# batch 76 training loss is : 0.18479
# batch 76 training accuracy is : 0.87500
# batch 77 training loss is : 0.01054
# batch 77 training accuracy is : 1.00000
# batch 78 training loss is : 0.02978
# batch 78 training accuracy is : 1.00000
# batch 79 training loss is : 0.15354
# batch 79 training accuracy is : 0.93750
# batch 80 training loss is : 0.21103
# batch 80 training accuracy is : 0.87500
# batch 81 training loss is : 0.09100
# batch 81 training accuracy is : 1.00000
# batch 82 training loss is : 0.14712
# batch 82 training accuracy is : 0.93750
# batch 83 training loss is : 0.30365
# batch 83 training accuracy is : 0.93750
# batch 84 training loss is : 0.15368
# batch 84 training accuracy is : 0.87500
# batch 85 training loss is : 0.05597
# batch 85 training accuracy is : 1.00000
# batch 86 training loss is : 0.01325
# batch 86 training accuracy is : 1.00000
# batch 87 training loss is : 0.04672
# batch 87 training accuracy is : 1.00000
# batch 88 training loss is : 0.10124
# batch 88 training accuracy is : 0.93750
# batch 89 training loss is : 0.13152
# batch 89 training accuracy is : 0.93750
# batch 90 training loss is : 0.40946
# batch 90 training accuracy is : 0.81250
# batch 91 training loss is : 0.15864
# batch 91 training accuracy is : 0.93750
# batch 92 training loss is : 0.06570
# batch 92 training accuracy is : 1.00000
# batch 93 training loss is : 0.00366
# batch 93 training accuracy is : 1.00000
# batch 94 training loss is : 0.12809
# batch 94 training accuracy is : 0.93750
# batch 95 training loss is : 0.09861
# batch 95 training accuracy is : 0.93750
# batch 96 training loss is : 0.21408
# batch 96 training accuracy is : 0.93750
# batch 97 training loss is : 0.26752
# batch 97 training accuracy is : 0.87500
# batch 98 training loss is : 0.04152
# batch 98 training accuracy is : 1.00000
# batch 99 training loss is : 0.07543
# batch 99 training accuracy is : 1.00000
# batch 100 training loss is : 0.22833
# batch 100 training accuracy is : 0.87500
# batch 101 training loss is : 0.11699
# batch 101 training accuracy is : 0.93750
# batch 102 training loss is : 0.17517
# batch 102 training accuracy is : 0.87500
# batch 103 training loss is : 0.05105
# batch 103 training accuracy is : 1.00000
# batch 104 training loss is : 0.00224
# batch 104 training accuracy is : 1.00000
# batch 105 training loss is : 0.00824
# batch 105 training accuracy is : 1.00000
# batch 106 training loss is : 0.05536
# batch 106 training accuracy is : 1.00000
# batch 107 training loss is : 0.04015
# batch 107 training accuracy is : 1.00000
# batch 108 training loss is : 0.09076
# batch 108 training accuracy is : 0.93750
# batch 109 training loss is : 0.13118
# batch 109 training accuracy is : 0.93750
# batch 110 training loss is : 0.30416
# batch 110 training accuracy is : 0.81250
# batch 111 training loss is : 0.00341
# batch 111 training accuracy is : 1.00000
# batch 112 training loss is : 0.22859
# batch 112 training accuracy is : 0.93750
# Average training loss is 0.19507 at the end of epoch 0
# Average training accuracy is 0.90445 at the end of epoch 0
# batch 0 dev loss is : 0.51851
# batch 0 dev accuracy is : 0.68750
# batch 1 dev loss is : 0.55285
# batch 1 dev accuracy is : 0.75000
# batch 2 dev loss is : 0.26949
# batch 2 dev accuracy is : 0.81250
# batch 3 dev loss is : 0.46090
# batch 3 dev accuracy is : 0.81250
# batch 4 dev loss is : 0.49499
# batch 4 dev accuracy is : 0.75000
# batch 5 dev loss is : 0.12836
# batch 5 dev accuracy is : 1.00000
# batch 6 dev loss is : 0.29792
# batch 6 dev accuracy is : 0.87500
# batch 7 dev loss is : 0.97116
# batch 7 dev accuracy is : 0.68750
# batch 8 dev loss is : 0.82065
# batch 8 dev accuracy is : 0.62500
# batch 9 dev loss is : 0.20819
# batch 9 dev accuracy is : 0.93750
# batch 10 dev loss is : 0.78288
# batch 10 dev accuracy is : 0.75000
# batch 11 dev loss is : 0.82145
# batch 11 dev accuracy is : 0.62500
# batch 12 dev loss is : 0.32017
# batch 12 dev accuracy is : 0.81250
# batch 13 dev loss is : 0.69996
# batch 13 dev accuracy is : 0.81250
# batch 14 dev loss is : 0.64428
# batch 14 dev accuracy is : 0.75000
# batch 15 dev loss is : 0.38823
# batch 15 dev accuracy is : 0.87500
# batch 16 dev loss is : 0.43006
# batch 16 dev accuracy is : 0.75000
# batch 17 dev loss is : 0.77556
# batch 17 dev accuracy is : 0.62500
# batch 18 dev loss is : 0.69473
# batch 18 dev accuracy is : 0.68750
# batch 19 dev loss is : 1.05040
# batch 19 dev accuracy is : 0.81250
# batch 20 dev loss is : 0.82031
# batch 20 dev accuracy is : 0.75000
# batch 21 dev loss is : 0.85284
# batch 21 dev accuracy is : 0.81250
# batch 22 dev loss is : 0.78213
# batch 22 dev accuracy is : 0.75000
# batch 23 dev loss is : 0.34647
# batch 23 dev accuracy is : 0.81250
# batch 24 dev loss is : 0.44124
# batch 24 dev accuracy is : 0.81250
# batch 25 dev loss is : 0.21998
# batch 25 dev accuracy is : 0.93750
# batch 26 dev loss is : 0.65348
# batch 26 dev accuracy is : 0.68750
# batch 27 dev loss is : 0.62920
# batch 27 dev accuracy is : 0.81250
# Average validation loss is 0.55676 at the end of epoch 0
# Average validation accuracy is 0.75541 at the end of epoch 0
# At 1-th epoch.
# batch 0 training loss is : 0.14520
# batch 0 training accuracy is : 0.93750
# batch 1 training loss is : 0.04555
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.07384
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.28918
# batch 3 training accuracy is : 0.87500
# batch 4 training loss is : 0.12355
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.05173
# batch 5 training accuracy is : 0.93750
# batch 6 training loss is : 0.24969
# batch 6 training accuracy is : 0.93750
# batch 7 training loss is : 0.25362
# batch 7 training accuracy is : 0.87500
# batch 8 training loss is : 0.01293
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.18437
# batch 9 training accuracy is : 0.93750
# batch 10 training loss is : 0.15541
# batch 10 training accuracy is : 0.93750
# batch 11 training loss is : 0.01685
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.27543
# batch 12 training accuracy is : 0.87500
# batch 13 training loss is : 0.02692
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.22965
# batch 14 training accuracy is : 0.81250
# batch 15 training loss is : 0.16643
# batch 15 training accuracy is : 0.87500
# batch 16 training loss is : 0.11594
# batch 16 training accuracy is : 0.93750
# batch 17 training loss is : 0.05200
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.59331
# batch 18 training accuracy is : 0.81250
# batch 19 training loss is : 0.16749
# batch 19 training accuracy is : 0.93750
# batch 20 training loss is : 0.17553
# batch 20 training accuracy is : 0.87500
# batch 21 training loss is : 0.05154
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00532
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.02158
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.44731
# batch 24 training accuracy is : 0.87500
# batch 25 training loss is : 0.23505
# batch 25 training accuracy is : 0.87500
# batch 26 training loss is : 0.53460
# batch 26 training accuracy is : 0.75000
# batch 27 training loss is : 0.02196
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.14233
# batch 28 training accuracy is : 0.93750
# batch 29 training loss is : 0.10175
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.26940
# batch 30 training accuracy is : 0.87500
# batch 31 training loss is : 0.03593
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.18007
# batch 32 training accuracy is : 0.93750
# batch 33 training loss is : 0.05439
# batch 33 training accuracy is : 0.93750
# batch 34 training loss is : 0.10665
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.07014
# batch 35 training accuracy is : 0.93750
# batch 36 training loss is : 0.14978
# batch 36 training accuracy is : 0.93750
# batch 37 training loss is : 0.20416
# batch 37 training accuracy is : 0.93750
# batch 38 training loss is : 0.22572
# batch 38 training accuracy is : 0.87500
# batch 39 training loss is : 0.07858
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00829
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.28072
# batch 41 training accuracy is : 0.93750
# batch 42 training loss is : 0.41036
# batch 42 training accuracy is : 0.93750
# batch 43 training loss is : 0.41727
# batch 43 training accuracy is : 0.87500
# batch 44 training loss is : 0.00997
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.16964
# batch 45 training accuracy is : 0.93750
# batch 46 training loss is : 0.12654
# batch 46 training accuracy is : 0.93750
# batch 47 training loss is : 0.20003
# batch 47 training accuracy is : 0.93750
# batch 48 training loss is : 0.08581
# batch 48 training accuracy is : 0.93750
# batch 49 training loss is : 0.29013
# batch 49 training accuracy is : 0.81250
# batch 50 training loss is : 0.21519
# batch 50 training accuracy is : 0.87500
# batch 51 training loss is : 0.00191
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.17089
# batch 52 training accuracy is : 0.93750
# batch 53 training loss is : 0.31472
# batch 53 training accuracy is : 0.81250
# batch 54 training loss is : 0.46510
# batch 54 training accuracy is : 0.81250
# batch 55 training loss is : 0.08891
# batch 55 training accuracy is : 0.93750
# batch 56 training loss is : 0.30102
# batch 56 training accuracy is : 0.87500
# batch 57 training loss is : 0.15252
# batch 57 training accuracy is : 1.00000
# batch 58 training loss is : 0.07101
# batch 58 training accuracy is : 1.00000
# batch 59 training loss is : 0.13070
# batch 59 training accuracy is : 0.93750
# batch 60 training loss is : 0.04987
# batch 60 training accuracy is : 1.00000
# batch 61 training loss is : 0.50662
# batch 61 training accuracy is : 0.75000
# batch 62 training loss is : 0.10860
# batch 62 training accuracy is : 0.93750
# batch 63 training loss is : 0.28904
# batch 63 training accuracy is : 0.87500
# batch 64 training loss is : 0.06734
# batch 64 training accuracy is : 1.00000
# batch 65 training loss is : 0.20052
# batch 65 training accuracy is : 0.87500
# batch 66 training loss is : 0.08030
# batch 66 training accuracy is : 0.93750
# batch 67 training loss is : 0.22153
# batch 67 training accuracy is : 0.93750
# batch 68 training loss is : 0.13612
# batch 68 training accuracy is : 0.87500
# batch 69 training loss is : 0.10408
# batch 69 training accuracy is : 0.87500
# batch 70 training loss is : 0.38705
# batch 70 training accuracy is : 0.81250
# batch 71 training loss is : 0.16528
# batch 71 training accuracy is : 0.93750
# batch 72 training loss is : 0.11475
# batch 72 training accuracy is : 0.87500
# batch 73 training loss is : 0.07483
# batch 73 training accuracy is : 1.00000
# batch 74 training loss is : 0.24793
# batch 74 training accuracy is : 0.93750
# batch 75 training loss is : 0.19052
# batch 75 training accuracy is : 0.87500
# batch 76 training loss is : 0.17437
# batch 76 training accuracy is : 0.87500
# batch 77 training loss is : 0.09289
# batch 77 training accuracy is : 1.00000
# batch 78 training loss is : 0.06284
# batch 78 training accuracy is : 1.00000
# batch 79 training loss is : 0.00431
# batch 79 training accuracy is : 1.00000
# batch 80 training loss is : 0.08941
# batch 80 training accuracy is : 1.00000
# batch 81 training loss is : 0.25569
# batch 81 training accuracy is : 0.93750
# batch 82 training loss is : 0.00403
# batch 82 training accuracy is : 1.00000
# batch 83 training loss is : 0.02436
# batch 83 training accuracy is : 1.00000
# batch 84 training loss is : 0.05821
# batch 84 training accuracy is : 1.00000
# batch 85 training loss is : 0.58272
# batch 85 training accuracy is : 0.87500
# batch 86 training loss is : 0.20947
# batch 86 training accuracy is : 0.87500
# batch 87 training loss is : 0.25475
# batch 87 training accuracy is : 0.81250
# batch 88 training loss is : 0.10911
# batch 88 training accuracy is : 0.93750
# batch 89 training loss is : 0.22006
# batch 89 training accuracy is : 0.87500
# batch 90 training loss is : 0.11124
# batch 90 training accuracy is : 0.93750
# batch 91 training loss is : 0.12351
# batch 91 training accuracy is : 0.93750
# batch 92 training loss is : 0.08207
# batch 92 training accuracy is : 1.00000
# batch 93 training loss is : 0.13915
# batch 93 training accuracy is : 0.93750
# batch 94 training loss is : 0.10503
# batch 94 training accuracy is : 1.00000
# batch 95 training loss is : 0.15272
# batch 95 training accuracy is : 0.93750
# batch 96 training loss is : 0.22970
# batch 96 training accuracy is : 0.93750
# batch 97 training loss is : 0.05482
# batch 97 training accuracy is : 1.00000
# batch 98 training loss is : 0.03190
# batch 98 training accuracy is : 1.00000
# batch 99 training loss is : 0.14406
# batch 99 training accuracy is : 0.93750
# batch 100 training loss is : 0.32172
# batch 100 training accuracy is : 0.87500
# batch 101 training loss is : 0.09874
# batch 101 training accuracy is : 0.93750
# batch 102 training loss is : 0.30745
# batch 102 training accuracy is : 0.87500
# batch 103 training loss is : 0.26306
# batch 103 training accuracy is : 0.87500
# batch 104 training loss is : 0.14143
# batch 104 training accuracy is : 0.93750
# batch 105 training loss is : 0.25017
# batch 105 training accuracy is : 0.87500
# batch 106 training loss is : 0.12167
# batch 106 training accuracy is : 0.93750
# batch 107 training loss is : 0.46141
# batch 107 training accuracy is : 0.68750
# batch 108 training loss is : 0.19955
# batch 108 training accuracy is : 0.87500
# batch 109 training loss is : 0.06561
# batch 109 training accuracy is : 1.00000
# batch 110 training loss is : 0.16871
# batch 110 training accuracy is : 0.87500
# batch 111 training loss is : 0.05426
# batch 111 training accuracy is : 0.93750
# batch 112 training loss is : 0.15630
# batch 112 training accuracy is : 0.93750
# Average training loss is 0.16802 at the end of epoch 1
# Average training accuracy is 0.92147 at the end of epoch 1
# batch 0 dev loss is : 0.50267
# batch 0 dev accuracy is : 0.75000
# batch 1 dev loss is : 0.41485
# batch 1 dev accuracy is : 0.81250
# batch 2 dev loss is : 0.22447
# batch 2 dev accuracy is : 0.87500
# batch 3 dev loss is : 0.51466
# batch 3 dev accuracy is : 0.81250
# batch 4 dev loss is : 0.48405
# batch 4 dev accuracy is : 0.68750
# batch 5 dev loss is : 0.17500
# batch 5 dev accuracy is : 0.93750
# batch 6 dev loss is : 0.29650
# batch 6 dev accuracy is : 0.87500
# batch 7 dev loss is : 0.92178
# batch 7 dev accuracy is : 0.81250
# batch 8 dev loss is : 0.70539
# batch 8 dev accuracy is : 0.62500
# batch 9 dev loss is : 0.22590
# batch 9 dev accuracy is : 0.87500
# batch 10 dev loss is : 0.90571
# batch 10 dev accuracy is : 0.56250
# batch 11 dev loss is : 0.61905
# batch 11 dev accuracy is : 0.62500
# batch 12 dev loss is : 0.29034
# batch 12 dev accuracy is : 0.81250
# batch 13 dev loss is : 0.90806
# batch 13 dev accuracy is : 0.81250
# batch 14 dev loss is : 0.64382
# batch 14 dev accuracy is : 0.75000
# batch 15 dev loss is : 0.42860
# batch 15 dev accuracy is : 0.87500
# batch 16 dev loss is : 0.47727
# batch 16 dev accuracy is : 0.68750
# batch 17 dev loss is : 0.96517
# batch 17 dev accuracy is : 0.68750
# batch 18 dev loss is : 0.78732
# batch 18 dev accuracy is : 0.68750
# batch 19 dev loss is : 1.05883
# batch 19 dev accuracy is : 0.81250
# batch 20 dev loss is : 0.80954
# batch 20 dev accuracy is : 0.81250
# batch 21 dev loss is : 0.82309
# batch 21 dev accuracy is : 0.81250
# batch 22 dev loss is : 0.76451
# batch 22 dev accuracy is : 0.81250
# batch 23 dev loss is : 0.29333
# batch 23 dev accuracy is : 0.87500
# batch 24 dev loss is : 0.38103
# batch 24 dev accuracy is : 0.87500
# batch 25 dev loss is : 0.37993
# batch 25 dev accuracy is : 0.75000
# batch 26 dev loss is : 0.53242
# batch 26 dev accuracy is : 0.75000
# batch 27 dev loss is : 0.61313
# batch 27 dev accuracy is : 0.81250
# Average validation loss is 0.55918 at the end of epoch 1
# Average validation accuracy is 0.75758 at the end of epoch 1
# At 2-th epoch.
# batch 0 training loss is : 0.12719
# batch 0 training accuracy is : 0.93750
# batch 1 training loss is : 0.17427
# batch 1 training accuracy is : 0.87500
# batch 2 training loss is : 0.08896
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.16414
# batch 3 training accuracy is : 0.87500
# batch 4 training loss is : 0.10867
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.07259
# batch 5 training accuracy is : 0.93750
# batch 6 training loss is : 0.17997
# batch 6 training accuracy is : 0.93750
# batch 7 training loss is : 0.14991
# batch 7 training accuracy is : 0.93750
# batch 8 training loss is : 0.15612
# batch 8 training accuracy is : 0.93750
# batch 9 training loss is : 0.05063
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.03877
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.45659
# batch 11 training accuracy is : 0.87500
# batch 12 training loss is : 0.33525
# batch 12 training accuracy is : 0.81250
# batch 13 training loss is : 0.06017
# batch 13 training accuracy is : 0.93750
# batch 14 training loss is : 0.28491
# batch 14 training accuracy is : 0.81250
# batch 15 training loss is : 0.26310
# batch 15 training accuracy is : 0.87500
# batch 16 training loss is : 0.11999
# batch 16 training accuracy is : 0.93750
# batch 17 training loss is : 0.18961
# batch 17 training accuracy is : 0.93750
# batch 18 training loss is : 0.53141
# batch 18 training accuracy is : 0.75000
# batch 19 training loss is : 0.00562
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.20826
# batch 20 training accuracy is : 0.87500
# batch 21 training loss is : 0.14100
# batch 21 training accuracy is : 0.93750
# batch 22 training loss is : 0.11569
# batch 22 training accuracy is : 0.93750
# batch 23 training loss is : 0.08957
# batch 23 training accuracy is : 0.93750
# batch 24 training loss is : 0.15454
# batch 24 training accuracy is : 0.93750
# batch 25 training loss is : 0.01614
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.12875
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.12766
# batch 27 training accuracy is : 0.93750
# batch 28 training loss is : 0.73338
# batch 28 training accuracy is : 0.62500
# batch 29 training loss is : 0.06803
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.70738
# batch 30 training accuracy is : 0.68750
# batch 31 training loss is : 0.13687
# batch 31 training accuracy is : 0.93750
# batch 32 training loss is : 0.20436
# batch 32 training accuracy is : 0.87500
# batch 33 training loss is : 0.15708
# batch 33 training accuracy is : 0.87500
# batch 34 training loss is : 0.04491
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.13358
# batch 35 training accuracy is : 0.93750
# batch 36 training loss is : 0.03769
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.13277
# batch 37 training accuracy is : 0.93750
# batch 38 training loss is : 0.31642
# batch 38 training accuracy is : 0.81250
# batch 39 training loss is : 0.12258
# batch 39 training accuracy is : 0.87500
# batch 40 training loss is : 0.00160
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.20797
# batch 41 training accuracy is : 0.87500
# batch 42 training loss is : 0.03669
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.21186
# batch 43 training accuracy is : 0.87500
# batch 44 training loss is : 0.24759
# batch 44 training accuracy is : 0.93750
# batch 45 training loss is : 0.05239
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.40810
# batch 46 training accuracy is : 0.87500
# batch 47 training loss is : 0.23262
# batch 47 training accuracy is : 0.81250
# batch 48 training loss is : 0.06592
# batch 48 training accuracy is : 0.93750
# batch 49 training loss is : 0.09453
# batch 49 training accuracy is : 0.93750
# batch 50 training loss is : 0.12099
# batch 50 training accuracy is : 0.93750
# batch 51 training loss is : 0.11925
# batch 51 training accuracy is : 0.87500
# batch 52 training loss is : 0.21040
# batch 52 training accuracy is : 0.93750
# batch 53 training loss is : 0.30672
# batch 53 training accuracy is : 0.87500
# batch 54 training loss is : 0.28096
# batch 54 training accuracy is : 0.87500
# batch 55 training loss is : 0.26093
# batch 55 training accuracy is : 0.87500
# batch 56 training loss is : 0.31764
# batch 56 training accuracy is : 0.87500
# batch 57 training loss is : 0.02105
# batch 57 training accuracy is : 1.00000
# batch 58 training loss is : 0.12207
# batch 58 training accuracy is : 0.87500
# batch 59 training loss is : 0.31840
# batch 59 training accuracy is : 0.87500
# batch 60 training loss is : 0.03280
# batch 60 training accuracy is : 1.00000
# batch 61 training loss is : 0.07455
# batch 61 training accuracy is : 0.93750
# batch 62 training loss is : 0.03542
# batch 62 training accuracy is : 1.00000
# batch 63 training loss is : 0.14362
# batch 63 training accuracy is : 0.87500
# batch 64 training loss is : 0.34607
# batch 64 training accuracy is : 0.87500
# batch 65 training loss is : 0.20003
# batch 65 training accuracy is : 0.93750
# batch 66 training loss is : 0.09588
# batch 66 training accuracy is : 0.93750
# batch 67 training loss is : 0.15327
# batch 67 training accuracy is : 0.93750
# batch 68 training loss is : 0.04108
# batch 68 training accuracy is : 1.00000
# batch 69 training loss is : 0.15472
# batch 69 training accuracy is : 0.93750
# batch 70 training loss is : 0.09333
# batch 70 training accuracy is : 0.93750
# batch 71 training loss is : 0.06767
# batch 71 training accuracy is : 0.93750
# batch 72 training loss is : 0.00698
# batch 72 training accuracy is : 1.00000
# batch 73 training loss is : 0.04976
# batch 73 training accuracy is : 1.00000
# batch 74 training loss is : 0.03556
# batch 74 training accuracy is : 1.00000
# batch 75 training loss is : 0.03322
# batch 75 training accuracy is : 1.00000
# batch 76 training loss is : 0.29897
# batch 76 training accuracy is : 0.93750
# batch 77 training loss is : 0.01735
# batch 77 training accuracy is : 1.00000
# batch 78 training loss is : 0.28944
# batch 78 training accuracy is : 0.87500
# batch 79 training loss is : 0.01406
# batch 79 training accuracy is : 1.00000
# batch 80 training loss is : 0.49541
# batch 80 training accuracy is : 0.87500
# batch 81 training loss is : 0.12854
# batch 81 training accuracy is : 0.93750
# batch 82 training loss is : 0.67973
# batch 82 training accuracy is : 0.81250
# batch 83 training loss is : 0.00912
# batch 83 training accuracy is : 1.00000
# batch 84 training loss is : 0.47204
# batch 84 training accuracy is : 0.81250
# batch 85 training loss is : 0.07152
# batch 85 training accuracy is : 1.00000
# batch 86 training loss is : 0.03391
# batch 86 training accuracy is : 1.00000
# batch 87 training loss is : 0.04250
# batch 87 training accuracy is : 1.00000
# batch 88 training loss is : 0.14812
# batch 88 training accuracy is : 0.93750
# batch 89 training loss is : 0.41479
# batch 89 training accuracy is : 0.81250
# batch 90 training loss is : 0.00759
# batch 90 training accuracy is : 1.00000
# batch 91 training loss is : 0.12476
# batch 91 training accuracy is : 0.93750
# batch 92 training loss is : 0.25267
# batch 92 training accuracy is : 0.87500
# batch 93 training loss is : 0.10803
# batch 93 training accuracy is : 0.93750
# batch 94 training loss is : 0.05372
# batch 94 training accuracy is : 1.00000
# batch 95 training loss is : 0.08556
# batch 95 training accuracy is : 1.00000
# batch 96 training loss is : 0.16591
# batch 96 training accuracy is : 0.93750
# batch 97 training loss is : 0.04450
# batch 97 training accuracy is : 1.00000
# batch 98 training loss is : 0.03972
# batch 98 training accuracy is : 1.00000
# batch 99 training loss is : 0.02827
# batch 99 training accuracy is : 1.00000
# batch 100 training loss is : 0.35084
# batch 100 training accuracy is : 0.87500
# batch 101 training loss is : 0.35040
# batch 101 training accuracy is : 0.81250
# batch 102 training loss is : 0.31768
# batch 102 training accuracy is : 0.87500
# batch 103 training loss is : 0.30312
# batch 103 training accuracy is : 0.87500
# batch 104 training loss is : 0.09391
# batch 104 training accuracy is : 1.00000
# batch 105 training loss is : 0.10558
# batch 105 training accuracy is : 0.93750
# batch 106 training loss is : 0.17583
# batch 106 training accuracy is : 0.93750
# batch 107 training loss is : 0.08872
# batch 107 training accuracy is : 1.00000
# batch 108 training loss is : 0.01959
# batch 108 training accuracy is : 1.00000
# batch 109 training loss is : 0.05242
# batch 109 training accuracy is : 0.93750
# batch 110 training loss is : 0.09549
# batch 110 training accuracy is : 0.93750
# batch 111 training loss is : 0.04736
# batch 111 training accuracy is : 1.00000
# batch 112 training loss is : 0.61349
# batch 112 training accuracy is : 0.75000
# Average training loss is 0.16849 at the end of epoch 2
# Average training accuracy is 0.91982 at the end of epoch 2
# batch 0 dev loss is : 0.58050
# batch 0 dev accuracy is : 0.87500
# batch 1 dev loss is : 0.38196
# batch 1 dev accuracy is : 0.87500
# batch 2 dev loss is : 0.24927
# batch 2 dev accuracy is : 0.87500
# batch 3 dev loss is : 0.34494
# batch 3 dev accuracy is : 0.81250
# batch 4 dev loss is : 0.59259
# batch 4 dev accuracy is : 0.75000
# batch 5 dev loss is : 0.33545
# batch 5 dev accuracy is : 0.75000
# batch 6 dev loss is : 0.14752
# batch 6 dev accuracy is : 0.93750
# batch 7 dev loss is : 1.24137
# batch 7 dev accuracy is : 0.75000
# batch 8 dev loss is : 0.56232
# batch 8 dev accuracy is : 0.68750
# batch 9 dev loss is : 0.22797
# batch 9 dev accuracy is : 0.87500
# batch 10 dev loss is : 0.79014
# batch 10 dev accuracy is : 0.75000
# batch 11 dev loss is : 1.39055
# batch 11 dev accuracy is : 0.56250
# batch 12 dev loss is : 0.77014
# batch 12 dev accuracy is : 0.68750
# batch 13 dev loss is : 1.26242
# batch 13 dev accuracy is : 0.68750
# batch 14 dev loss is : 1.36817
# batch 14 dev accuracy is : 0.75000
# batch 15 dev loss is : 0.50319
# batch 15 dev accuracy is : 0.87500
# batch 16 dev loss is : 0.63775
# batch 16 dev accuracy is : 0.68750
# batch 17 dev loss is : 1.11635
# batch 17 dev accuracy is : 0.56250
# batch 18 dev loss is : 0.59835
# batch 18 dev accuracy is : 0.62500
# batch 19 dev loss is : 1.54675
# batch 19 dev accuracy is : 0.81250
# batch 20 dev loss is : 1.40247
# batch 20 dev accuracy is : 0.62500
# batch 21 dev loss is : 1.58408
# batch 21 dev accuracy is : 0.62500
# batch 22 dev loss is : 0.96254
# batch 22 dev accuracy is : 0.93750
# batch 23 dev loss is : 0.41660
# batch 23 dev accuracy is : 0.87500
# batch 24 dev loss is : 0.37374
# batch 24 dev accuracy is : 0.75000
# batch 25 dev loss is : 0.83460
# batch 25 dev accuracy is : 0.62500
# batch 26 dev loss is : 1.51855
# batch 26 dev accuracy is : 0.62500
# batch 27 dev loss is : 1.19085
# batch 27 dev accuracy is : 0.68750
# Average validation loss is 0.79415 at the end of epoch 2
# Average validation accuracy is 0.72511 at the end of epoch 2
# At 3-th epoch.
# batch 0 training loss is : 0.54500
# batch 0 training accuracy is : 0.81250
# batch 1 training loss is : 0.03654
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.18278
# batch 2 training accuracy is : 0.93750
# batch 3 training loss is : 0.10840
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.14784
# batch 4 training accuracy is : 0.93750
# batch 5 training loss is : 0.11867
# batch 5 training accuracy is : 0.93750
# batch 6 training loss is : 0.04494
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.09094
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.06275
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.10585
# batch 9 training accuracy is : 0.87500
# batch 10 training loss is : 0.07115
# batch 10 training accuracy is : 0.93750
# batch 11 training loss is : 0.27209
# batch 11 training accuracy is : 0.93750
# batch 12 training loss is : 0.14555
# batch 12 training accuracy is : 0.93750
# batch 13 training loss is : 0.31480
# batch 13 training accuracy is : 0.81250
# batch 14 training loss is : 0.26882
# batch 14 training accuracy is : 0.93750
# batch 15 training loss is : 0.17519
# batch 15 training accuracy is : 0.87500
# batch 16 training loss is : 0.07836
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.16931
# batch 17 training accuracy is : 0.93750
# batch 18 training loss is : 0.12677
# batch 18 training accuracy is : 0.93750
# batch 19 training loss is : 0.21265
# batch 19 training accuracy is : 0.93750
# batch 20 training loss is : 0.14674
# batch 20 training accuracy is : 0.87500
# batch 21 training loss is : 0.12428
# batch 21 training accuracy is : 0.87500
# batch 22 training loss is : 0.04428
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.11767
# batch 23 training accuracy is : 0.93750
# batch 24 training loss is : 0.17181
# batch 24 training accuracy is : 0.87500
# batch 25 training loss is : 0.06404
# batch 25 training accuracy is : 0.93750
# batch 26 training loss is : 0.00162
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.15760
# batch 27 training accuracy is : 0.93750
# batch 28 training loss is : 0.13675
# batch 28 training accuracy is : 0.93750
# batch 29 training loss is : 0.04377
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.26891
# batch 30 training accuracy is : 0.81250
# batch 31 training loss is : 0.10316
# batch 31 training accuracy is : 0.93750
# batch 32 training loss is : 0.07900
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.15145
# batch 33 training accuracy is : 0.93750
# batch 34 training loss is : 0.10030
# batch 34 training accuracy is : 0.93750
# batch 35 training loss is : 0.19146
# batch 35 training accuracy is : 0.93750
# batch 36 training loss is : 0.00930
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.50574
# batch 37 training accuracy is : 0.81250
# batch 38 training loss is : 0.11866
# batch 38 training accuracy is : 0.93750
# batch 39 training loss is : 0.09429
# batch 39 training accuracy is : 0.93750
# batch 40 training loss is : 0.39033
# batch 40 training accuracy is : 0.81250
# batch 41 training loss is : 0.01901
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.12096
# batch 42 training accuracy is : 0.93750
# batch 43 training loss is : 0.21975
# batch 43 training accuracy is : 0.87500
# batch 44 training loss is : 0.09414
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.40482
# batch 45 training accuracy is : 0.81250
# batch 46 training loss is : 0.01511
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.10355
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.34867
# batch 48 training accuracy is : 0.87500
# batch 49 training loss is : 0.14059
# batch 49 training accuracy is : 0.93750
# batch 50 training loss is : 0.01743
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.07065
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.14604
# batch 52 training accuracy is : 0.93750
# batch 53 training loss is : 0.23037
# batch 53 training accuracy is : 0.87500
# batch 54 training loss is : 0.14227
# batch 54 training accuracy is : 0.93750
# batch 55 training loss is : 0.11178
# batch 55 training accuracy is : 0.93750
# batch 56 training loss is : 0.01487
# batch 56 training accuracy is : 1.00000
# batch 57 training loss is : 0.26739
# batch 57 training accuracy is : 0.87500
# batch 58 training loss is : 0.09858
# batch 58 training accuracy is : 1.00000
# batch 59 training loss is : 0.25586
# batch 59 training accuracy is : 0.93750
# batch 60 training loss is : 0.02181
# batch 60 training accuracy is : 1.00000
# batch 61 training loss is : 0.11272
# batch 61 training accuracy is : 0.93750
# batch 62 training loss is : 0.08457
# batch 62 training accuracy is : 1.00000
# batch 63 training loss is : 0.06734
# batch 63 training accuracy is : 0.93750
# batch 64 training loss is : 0.20251
# batch 64 training accuracy is : 0.87500
# batch 65 training loss is : 0.05668
# batch 65 training accuracy is : 1.00000
# batch 66 training loss is : 0.52358
# batch 66 training accuracy is : 0.81250
# batch 67 training loss is : 0.45618
# batch 67 training accuracy is : 0.81250
# batch 68 training loss is : 0.25707
# batch 68 training accuracy is : 0.93750
# batch 69 training loss is : 0.03697
# batch 69 training accuracy is : 1.00000
# batch 70 training loss is : 0.25614
# batch 70 training accuracy is : 0.93750
# batch 71 training loss is : 0.01094
# batch 71 training accuracy is : 1.00000
# batch 72 training loss is : 0.06585
# batch 72 training accuracy is : 1.00000
# batch 73 training loss is : 0.06055
# batch 73 training accuracy is : 0.93750
# batch 74 training loss is : 0.26047
# batch 74 training accuracy is : 0.93750
# batch 75 training loss is : 0.19760
# batch 75 training accuracy is : 0.87500
# batch 76 training loss is : 0.20670
# batch 76 training accuracy is : 0.93750
# batch 77 training loss is : 0.08452
# batch 77 training accuracy is : 0.93750
# batch 78 training loss is : 0.07220
# batch 78 training accuracy is : 0.93750
# batch 79 training loss is : 0.33543
# batch 79 training accuracy is : 0.87500
# batch 80 training loss is : 0.01133
# batch 80 training accuracy is : 1.00000
# batch 81 training loss is : 0.03005
# batch 81 training accuracy is : 1.00000
# batch 82 training loss is : 0.00050
# batch 82 training accuracy is : 1.00000
# batch 83 training loss is : 0.00255
# batch 83 training accuracy is : 1.00000
# batch 84 training loss is : 0.01747
# batch 84 training accuracy is : 1.00000
# batch 85 training loss is : 0.14773
# batch 85 training accuracy is : 0.93750
# batch 86 training loss is : 0.10672
# batch 86 training accuracy is : 0.93750
# batch 87 training loss is : 0.36877
# batch 87 training accuracy is : 0.81250
# batch 88 training loss is : 0.17854
# batch 88 training accuracy is : 0.87500
# batch 89 training loss is : 0.21758
# batch 89 training accuracy is : 0.87500
# batch 90 training loss is : 0.25236
# batch 90 training accuracy is : 0.87500
# batch 91 training loss is : 0.09506
# batch 91 training accuracy is : 0.93750
# batch 92 training loss is : 0.17683
# batch 92 training accuracy is : 0.93750
# batch 93 training loss is : 0.11198
# batch 93 training accuracy is : 1.00000
# batch 94 training loss is : 0.25889
# batch 94 training accuracy is : 0.93750
# batch 95 training loss is : 0.19166
# batch 95 training accuracy is : 0.93750
# batch 96 training loss is : 0.04341
# batch 96 training accuracy is : 1.00000
# batch 97 training loss is : 0.59801
# batch 97 training accuracy is : 0.87500
# batch 98 training loss is : 0.16339
# batch 98 training accuracy is : 0.93750
# batch 99 training loss is : 0.07333
# batch 99 training accuracy is : 1.00000
# batch 100 training loss is : 0.06264
# batch 100 training accuracy is : 1.00000
# batch 101 training loss is : 0.04078
# batch 101 training accuracy is : 1.00000
# batch 102 training loss is : 0.44971
# batch 102 training accuracy is : 0.75000
# batch 103 training loss is : 0.05384
# batch 103 training accuracy is : 1.00000
# batch 104 training loss is : 0.15950
# batch 104 training accuracy is : 0.93750
# batch 105 training loss is : 0.05465
# batch 105 training accuracy is : 0.93750
# batch 106 training loss is : 0.33405
# batch 106 training accuracy is : 0.87500
# batch 107 training loss is : 0.23059
# batch 107 training accuracy is : 0.87500
# batch 108 training loss is : 0.11228
# batch 108 training accuracy is : 0.93750
# batch 109 training loss is : 0.46088
# batch 109 training accuracy is : 0.75000
# batch 110 training loss is : 0.00088
# batch 110 training accuracy is : 1.00000
# batch 111 training loss is : 0.04467
# batch 111 training accuracy is : 1.00000
# batch 112 training loss is : 0.11631
# batch 112 training accuracy is : 0.93750
# Average training loss is 0.15515 at the end of epoch 3
# Average training accuracy is 0.92861 at the end of epoch 3
# batch 0 dev loss is : 0.98314
# batch 0 dev accuracy is : 0.75000
# batch 1 dev loss is : 0.85425
# batch 1 dev accuracy is : 0.81250
# batch 2 dev loss is : 0.75648
# batch 2 dev accuracy is : 0.75000
# batch 3 dev loss is : 0.97296
# batch 3 dev accuracy is : 0.81250
# batch 4 dev loss is : 0.77263
# batch 4 dev accuracy is : 0.62500
# batch 5 dev loss is : 0.38743
# batch 5 dev accuracy is : 0.87500
# batch 6 dev loss is : 0.73082
# batch 6 dev accuracy is : 0.68750
# batch 7 dev loss is : 1.25817
# batch 7 dev accuracy is : 0.68750
# batch 8 dev loss is : 1.20370
# batch 8 dev accuracy is : 0.62500
# batch 9 dev loss is : 0.51430
# batch 9 dev accuracy is : 0.81250
# batch 10 dev loss is : 1.89646
# batch 10 dev accuracy is : 0.56250
# batch 11 dev loss is : 0.82986
# batch 11 dev accuracy is : 0.68750
# batch 12 dev loss is : 0.45363
# batch 12 dev accuracy is : 0.87500
# batch 13 dev loss is : 1.09200
# batch 13 dev accuracy is : 0.62500
# batch 14 dev loss is : 0.57017
# batch 14 dev accuracy is : 0.87500
# batch 15 dev loss is : 0.79468
# batch 15 dev accuracy is : 0.81250
# batch 16 dev loss is : 0.72635
# batch 16 dev accuracy is : 0.87500
# batch 17 dev loss is : 1.54122
# batch 17 dev accuracy is : 0.75000
# batch 18 dev loss is : 1.78910
# batch 18 dev accuracy is : 0.56250
# batch 19 dev loss is : 1.23436
# batch 19 dev accuracy is : 0.75000
# batch 20 dev loss is : 1.01056
# batch 20 dev accuracy is : 0.81250
# batch 21 dev loss is : 0.90134
# batch 21 dev accuracy is : 0.68750
# batch 22 dev loss is : 1.26845
# batch 22 dev accuracy is : 0.68750
# batch 23 dev loss is : 0.69666
# batch 23 dev accuracy is : 0.75000
# batch 24 dev loss is : 0.84296
# batch 24 dev accuracy is : 0.75000
# batch 25 dev loss is : 0.47298
# batch 25 dev accuracy is : 0.87500
# batch 26 dev loss is : 0.72182
# batch 26 dev accuracy is : 0.75000
# batch 27 dev loss is : 0.57205
# batch 27 dev accuracy is : 0.81250
# Average validation loss is 0.89519 at the end of epoch 3
# Average validation accuracy is 0.72511 at the end of epoch 3
# At 4-th epoch.
# batch 0 training loss is : 0.09620
# batch 0 training accuracy is : 0.93750
# batch 1 training loss is : 0.04079
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.28471
# batch 2 training accuracy is : 0.87500
# batch 3 training loss is : 0.33634
# batch 3 training accuracy is : 0.87500
# batch 4 training loss is : 0.09412
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.20605
# batch 5 training accuracy is : 0.87500
# batch 6 training loss is : 0.07336
# batch 6 training accuracy is : 0.93750
# batch 7 training loss is : 0.60899
# batch 7 training accuracy is : 0.75000
# batch 8 training loss is : 0.07641
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00667
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.30053
# batch 10 training accuracy is : 0.75000
# batch 11 training loss is : 0.18313
# batch 11 training accuracy is : 0.87500
# batch 12 training loss is : 0.08515
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.08684
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.18706
# batch 14 training accuracy is : 0.87500
# batch 15 training loss is : 0.01017
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.15046
# batch 16 training accuracy is : 0.87500
# batch 17 training loss is : 0.41023
# batch 17 training accuracy is : 0.81250
# batch 18 training loss is : 0.04993
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.03558
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.49565
# batch 20 training accuracy is : 0.68750
# batch 21 training loss is : 0.25862
# batch 21 training accuracy is : 0.93750
# batch 22 training loss is : 0.12537
# batch 22 training accuracy is : 0.93750
# batch 23 training loss is : 0.09873
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.20902
# batch 24 training accuracy is : 0.93750
# batch 25 training loss is : 0.16345
# batch 25 training accuracy is : 0.87500
# batch 26 training loss is : 0.05869
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.13829
# batch 27 training accuracy is : 0.93750
# batch 28 training loss is : 0.06142
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.12466
# batch 29 training accuracy is : 0.87500
# batch 30 training loss is : 0.12431
# batch 30 training accuracy is : 0.93750
# batch 31 training loss is : 0.05040
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.21091
# batch 32 training accuracy is : 0.87500
# batch 33 training loss is : 0.13738
# batch 33 training accuracy is : 0.93750
# batch 34 training loss is : 0.04323
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.03506
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.37346
# batch 36 training accuracy is : 0.81250
# batch 37 training loss is : 0.15907
# batch 37 training accuracy is : 0.93750
# batch 38 training loss is : 0.08828
# batch 38 training accuracy is : 0.93750
# batch 39 training loss is : 0.25997
# batch 39 training accuracy is : 0.93750
# batch 40 training loss is : 0.04333
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.24764
# batch 41 training accuracy is : 0.87500
# batch 42 training loss is : 0.17755
# batch 42 training accuracy is : 0.93750
# batch 43 training loss is : 0.07510
# batch 43 training accuracy is : 0.93750
# batch 44 training loss is : 0.04449
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.31546
# batch 45 training accuracy is : 0.87500
# batch 46 training loss is : 0.10957
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.15236
# batch 47 training accuracy is : 0.93750
# batch 48 training loss is : 0.30120
# batch 48 training accuracy is : 0.87500
# batch 49 training loss is : 0.17477
# batch 49 training accuracy is : 0.93750
# batch 50 training loss is : 0.06539
# batch 50 training accuracy is : 0.93750
# batch 51 training loss is : 0.10583
# batch 51 training accuracy is : 0.93750
# batch 52 training loss is : 0.07317
# batch 52 training accuracy is : 0.93750
# batch 53 training loss is : 0.42950
# batch 53 training accuracy is : 0.75000
# batch 54 training loss is : 0.40364
# batch 54 training accuracy is : 0.75000
# batch 55 training loss is : 0.12616
# batch 55 training accuracy is : 0.93750
# batch 56 training loss is : 0.12490
# batch 56 training accuracy is : 0.93750
# batch 57 training loss is : 0.00659
# batch 57 training accuracy is : 1.00000
# batch 58 training loss is : 0.08627
# batch 58 training accuracy is : 0.93750
# batch 59 training loss is : 0.00807
# batch 59 training accuracy is : 1.00000
# batch 60 training loss is : 0.32036
# batch 60 training accuracy is : 0.81250
# batch 61 training loss is : 0.12257
# batch 61 training accuracy is : 0.93750
# batch 62 training loss is : 0.00029
# batch 62 training accuracy is : 1.00000
# batch 63 training loss is : 0.01613
# batch 63 training accuracy is : 1.00000
# batch 64 training loss is : 0.05306
# batch 64 training accuracy is : 1.00000
# batch 65 training loss is : 0.16368
# batch 65 training accuracy is : 0.93750
# batch 66 training loss is : 0.17459
# batch 66 training accuracy is : 0.93750
# batch 67 training loss is : 0.16500
# batch 67 training accuracy is : 0.93750
# batch 68 training loss is : 0.26185
# batch 68 training accuracy is : 0.93750
# batch 69 training loss is : 0.03466
# batch 69 training accuracy is : 1.00000
# ...
# batch 71 training loss is : 0.38952
# batch 71 training accuracy is : 0.81250
# batch 72 training loss is : 0.06302
# batch 72 training accuracy is : 0.93750
# batch 73 training loss is : 0.07733
# batch 73 training accuracy is : 0.93750
# batch 74 training loss is : 0.01036
# batch 74 training accuracy is : 1.00000
# batch 75 training loss is : 0.02233
# batch 75 training accuracy is : 1.00000
# batch 76 training loss is : 0.02894
# batch 76 training accuracy is : 1.00000
# batch 77 training loss is : 0.16365
# batch 77 training accuracy is : 0.87500
# batch 78 training loss is : 0.02547
# batch 78 training accuracy is : 1.00000
# batch 79 training loss is : 0.01189
# batch 79 training accuracy is : 1.00000
# batch 80 training loss is : 0.00203
# batch 80 training accuracy is : 1.00000
# batch 81 training loss is : 0.00829
# batch 81 training accuracy is : 1.00000
# batch 82 training loss is : 0.00168
# batch 82 training accuracy is : 1.00000
# batch 83 training loss is : 0.00058
# batch 83 training accuracy is : 1.00000
# batch 84 training loss is : 0.11157
# batch 84 training accuracy is : 0.93750
# batch 85 training loss is : 0.00425
# batch 85 training accuracy is : 1.00000
# batch 86 training loss is : 0.21343
# batch 86 training accuracy is : 0.93750
# batch 87 training loss is : 0.05145
# batch 87 training accuracy is : 1.00000
# batch 88 training loss is : 0.00121
# batch 88 training accuracy is : 1.00000
# batch 89 training loss is : 0.00986
# batch 89 training accuracy is : 1.00000
# batch 90 training loss is : 0.00000
# batch 90 training accuracy is : 1.00000
# batch 91 training loss is : 0.00643
# batch 91 training accuracy is : 1.00000
# batch 92 training loss is : 0.11272
# batch 92 training accuracy is : 0.93750
# batch 93 training loss is : 0.22812
# batch 93 training accuracy is : 0.93750
# batch 94 training loss is : 0.02002
# batch 94 training accuracy is : 1.00000
# batch 95 training loss is : 0.01012
# batch 95 training accuracy is : 1.00000
# batch 96 training loss is : 0.00933
# batch 96 training accuracy is : 1.00000
# batch 97 training loss is : 0.02024
# batch 97 training accuracy is : 1.00000
# batch 98 training loss is : 0.00251
# batch 98 training accuracy is : 1.00000
# batch 99 training loss is : 0.11714
# batch 99 training accuracy is : 0.93750
# batch 100 training loss is : 0.03224
# batch 100 training accuracy is : 1.00000
# batch 101 training loss is : 0.05286
# batch 101 training accuracy is : 1.00000
# batch 102 training loss is : 0.09939
# batch 102 training accuracy is : 0.93750
# batch 103 training loss is : 0.24961
# batch 103 training accuracy is : 0.87500
# batch 104 training loss is : 0.00156
# batch 104 training accuracy is : 1.00000
# batch 105 training loss is : 0.01578
# batch 105 training accuracy is : 1.00000
# batch 106 training loss is : 0.07721
# batch 106 training accuracy is : 0.93750
# batch 107 training loss is : 0.03254
# batch 107 training accuracy is : 1.00000
# batch 108 training loss is : 0.07933
# batch 108 training accuracy is : 0.93750
# batch 109 training loss is : 0.00487
# batch 109 training accuracy is : 1.00000
# batch 110 training loss is : 0.09039
# batch 110 training accuracy is : 0.93750
# batch 111 training loss is : 0.10688
# batch 111 training accuracy is : 0.93750
# batch 112 training loss is : 0.00071
# batch 112 training accuracy is : 1.00000
# Average training loss is 0.05730 at the end of epoch 198
# Average training accuracy is 0.96650 at the end of epoch 198
# batch 0 dev loss is : 1.41527
# batch 0 dev accuracy is : 0.81250
# batch 1 dev loss is : 0.18463
# batch 1 dev accuracy is : 0.87500
# batch 2 dev loss is : 0.67742
# batch 2 dev accuracy is : 0.87500
# batch 3 dev loss is : 0.90317
# batch 3 dev accuracy is : 0.81250
# batch 4 dev loss is : 0.81668
# batch 4 dev accuracy is : 0.81250
# batch 5 dev loss is : 0.64762
# batch 5 dev accuracy is : 0.81250
# batch 6 dev loss is : 1.02965
# batch 6 dev accuracy is : 0.68750
# batch 7 dev loss is : 2.17644
# batch 7 dev accuracy is : 0.81250
# batch 8 dev loss is : 2.35950
# batch 8 dev accuracy is : 0.62500
# batch 9 dev loss is : 0.67722
# batch 9 dev accuracy is : 0.81250
# batch 10 dev loss is : 1.93260
# batch 10 dev accuracy is : 0.56250
# batch 11 dev loss is : 3.43958
# batch 11 dev accuracy is : 0.62500
# batch 12 dev loss is : 1.73305
# batch 12 dev accuracy is : 0.81250
# batch 13 dev loss is : 2.23792
# batch 13 dev accuracy is : 0.62500
# batch 14 dev loss is : 1.81253
# batch 14 dev accuracy is : 0.68750
# batch 15 dev loss is : 1.16736
# batch 15 dev accuracy is : 0.87500
# batch 16 dev loss is : 1.02835
# batch 16 dev accuracy is : 0.81250
# batch 17 dev loss is : 3.06481
# batch 17 dev accuracy is : 0.62500
# batch 18 dev loss is : 2.50926
# batch 18 dev accuracy is : 0.75000
# batch 19 dev loss is : 2.78672
# batch 19 dev accuracy is : 0.81250
# batch 20 dev loss is : 2.28264
# batch 20 dev accuracy is : 0.62500
# batch 21 dev loss is : 2.88293
# batch 21 dev accuracy is : 0.75000
# batch 22 dev loss is : 1.62117
# batch 22 dev accuracy is : 0.81250
# batch 23 dev loss is : 0.29010
# batch 23 dev accuracy is : 0.81250
# batch 24 dev loss is : 0.68298
# batch 24 dev accuracy is : 0.81250
# batch 25 dev loss is : 1.91029
# batch 25 dev accuracy is : 0.56250
# batch 26 dev loss is : 2.88295
# batch 26 dev accuracy is : 0.68750
# batch 27 dev loss is : 1.68954
# batch 27 dev accuracy is : 0.75000
# Average validation loss is 1.62225 at the end of epoch 198
# Average validation accuracy is 0.72511 at the end of epoch 198
# At 199-th epoch.
# batch 0 training loss is : 0.02161
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.10315
# batch 1 training accuracy is : 0.93750
# batch 2 training loss is : 0.00960
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.02810
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.18285
# batch 4 training accuracy is : 0.93750
# batch 5 training loss is : 0.04933
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.49619
# batch 6 training accuracy is : 0.93750
# batch 7 training loss is : 0.00147
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.27646
# batch 8 training accuracy is : 0.93750
# batch 9 training loss is : 0.00403
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.05356
# batch 10 training accuracy is : 0.93750
# batch 11 training loss is : 0.03231
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00008
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.14679
# batch 13 training accuracy is : 0.93750
# batch 14 training loss is : 0.03848
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00781
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.06842
# batch 16 training accuracy is : 0.93750
# batch 17 training loss is : 0.02837
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.19751
# batch 18 training accuracy is : 0.87500
# batch 19 training loss is : 0.01923
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00946
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.21996
# batch 21 training accuracy is : 0.93750
# batch 22 training loss is : 0.00024
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.13125
# batch 23 training accuracy is : 0.93750
# batch 24 training loss is : 0.08664
# batch 24 training accuracy is : 0.93750
# batch 25 training loss is : 0.01011
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.16209
# batch 26 training accuracy is : 0.93750
# batch 27 training loss is : 0.05149
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.13321
# batch 28 training accuracy is : 0.93750
# batch 29 training loss is : 0.08419
# batch 29 training accuracy is : 0.93750
# batch 30 training loss is : 0.02733
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.07569
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.32809
# batch 32 training accuracy is : 0.87500
# batch 33 training loss is : 0.00119
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.09328
# batch 34 training accuracy is : 0.93750
# batch 35 training loss is : 0.27034
# batch 35 training accuracy is : 0.93750
# batch 36 training loss is : 0.10500
# batch 36 training accuracy is : 0.93750
# batch 37 training loss is : 0.00835
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.09002
# batch 38 training accuracy is : 0.93750
# batch 39 training loss is : 0.00303
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.01719
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.01493
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00221
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.08723
# batch 43 training accuracy is : 0.93750
# batch 44 training loss is : 0.14060
# batch 44 training accuracy is : 0.93750
# batch 45 training loss is : 0.20626
# batch 45 training accuracy is : 0.87500
# batch 46 training loss is : 0.00920
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.16108
# batch 47 training accuracy is : 0.87500
# batch 48 training loss is : 0.00856
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00090
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00185
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.00103
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00067
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00489
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.54378
# batch 54 training accuracy is : 0.75000
# batch 55 training loss is : 0.04766
# batch 55 training accuracy is : 0.93750
# batch 56 training loss is : 0.06960
# batch 56 training accuracy is : 1.00000
# batch 57 training loss is : 0.00245
# batch 57 training accuracy is : 1.00000
# batch 58 training loss is : 0.00737
# batch 58 training accuracy is : 1.00000
# batch 59 training loss is : 0.08068
# batch 59 training accuracy is : 0.93750
# batch 60 training loss is : 0.00430
# batch 60 training accuracy is : 1.00000
# batch 61 training loss is : 0.02105
# batch 61 training accuracy is : 1.00000
# batch 62 training loss is : 0.06194
# batch 62 training accuracy is : 1.00000
# batch 63 training loss is : 0.21757
# batch 63 training accuracy is : 0.93750
# batch 64 training loss is : 0.00615
# batch 64 training accuracy is : 1.00000
# batch 65 training loss is : 0.00907
# batch 65 training accuracy is : 1.00000
# batch 66 training loss is : 0.18025
# batch 66 training accuracy is : 0.87500
# batch 67 training loss is : 0.08560
# batch 67 training accuracy is : 1.00000
# batch 68 training loss is : 0.03631
# batch 68 training accuracy is : 1.00000
# batch 69 training loss is : 0.00000
# batch 69 training accuracy is : 1.00000
# batch 70 training loss is : 0.06145
# batch 70 training accuracy is : 0.93750
# batch 71 training loss is : 0.01315
# batch 71 training accuracy is : 1.00000
# batch 72 training loss is : 0.00031
# batch 72 training accuracy is : 1.00000
# batch 73 training loss is : 0.05497
# batch 73 training accuracy is : 1.00000
# batch 74 training loss is : 0.01218
# batch 74 training accuracy is : 1.00000
# batch 75 training loss is : 0.09187
# batch 75 training accuracy is : 0.93750
# batch 76 training loss is : 0.00369
# batch 76 training accuracy is : 1.00000
# batch 77 training loss is : 0.00294
# batch 77 training accuracy is : 1.00000
# batch 78 training loss is : 0.01013
# batch 78 training accuracy is : 1.00000
# batch 79 training loss is : 0.01729
# batch 79 training accuracy is : 1.00000
# batch 80 training loss is : 0.06451
# batch 80 training accuracy is : 1.00000
# batch 81 training loss is : 0.00951
# batch 81 training accuracy is : 1.00000
# batch 82 training loss is : 0.02541
# batch 82 training accuracy is : 1.00000
# batch 83 training loss is : 0.11755
# batch 83 training accuracy is : 0.93750
# batch 84 training loss is : 0.06244
# batch 84 training accuracy is : 1.00000
# batch 85 training loss is : 0.03894
# batch 85 training accuracy is : 1.00000
# batch 86 training loss is : 0.01564
# batch 86 training accuracy is : 1.00000
# batch 87 training loss is : 0.05173
# batch 87 training accuracy is : 0.93750
# batch 88 training loss is : 0.17291
# batch 88 training accuracy is : 0.93750
# batch 89 training loss is : 0.02416
# batch 89 training accuracy is : 1.00000
# batch 90 training loss is : 0.00000
# batch 90 training accuracy is : 1.00000
# batch 91 training loss is : 0.09776
# batch 91 training accuracy is : 0.93750
# batch 92 training loss is : 0.00374
# batch 92 training accuracy is : 1.00000
# batch 93 training loss is : 0.07088
# batch 93 training accuracy is : 0.93750
# batch 94 training loss is : 0.00966
# batch 94 training accuracy is : 1.00000
# batch 95 training loss is : 0.08567
# batch 95 training accuracy is : 0.93750
# batch 96 training loss is : 0.00686
# batch 96 training accuracy is : 1.00000
# batch 97 training loss is : 0.00624
# batch 97 training accuracy is : 1.00000
# batch 98 training loss is : 0.00384
# batch 98 training accuracy is : 1.00000
# batch 99 training loss is : 0.00776
# batch 99 training accuracy is : 1.00000
# batch 100 training loss is : 0.30429
# batch 100 training accuracy is : 0.93750
# batch 101 training loss is : 0.00263
# batch 101 training accuracy is : 1.00000
# batch 102 training loss is : 0.05072
# batch 102 training accuracy is : 0.93750
# batch 103 training loss is : 0.18074
# batch 103 training accuracy is : 0.93750
# batch 104 training loss is : 0.11049
# batch 104 training accuracy is : 0.93750
# batch 105 training loss is : 0.11449
# batch 105 training accuracy is : 0.93750
# batch 106 training loss is : 0.02547
# batch 106 training accuracy is : 1.00000
# batch 107 training loss is : 0.13135
# batch 107 training accuracy is : 0.93750
# batch 108 training loss is : 0.00000
# batch 108 training accuracy is : 1.00000
# batch 109 training loss is : 0.01568
# batch 109 training accuracy is : 1.00000
# batch 110 training loss is : 0.00025
# batch 110 training accuracy is : 1.00000
# batch 111 training loss is : 0.02126
# batch 111 training accuracy is : 1.00000
# batch 112 training loss is : 0.01134
# batch 112 training accuracy is : 1.00000
# Average training loss is 0.06852 at the end of epoch 199
# Average training accuracy is 0.96540 at the end of epoch 199
# batch 0 dev loss is : 0.95366
# batch 0 dev accuracy is : 0.75000
# batch 1 dev loss is : 0.85396
# batch 1 dev accuracy is : 0.87500
# batch 2 dev loss is : 0.84534
# batch 2 dev accuracy is : 0.87500
# batch 3 dev loss is : 1.24312
# batch 3 dev accuracy is : 0.81250
# batch 4 dev loss is : 0.84376
# batch 4 dev accuracy is : 0.81250
# batch 5 dev loss is : 0.66819
# batch 5 dev accuracy is : 0.87500
# batch 6 dev loss is : 1.16452
# batch 6 dev accuracy is : 0.68750
# batch 7 dev loss is : 2.26858
# batch 7 dev accuracy is : 0.75000
# batch 8 dev loss is : 1.88812
# batch 8 dev accuracy is : 0.62500
# batch 9 dev loss is : 0.85057
# batch 9 dev accuracy is : 0.81250
# batch 10 dev loss is : 2.05448
# batch 10 dev accuracy is : 0.56250
# batch 11 dev loss is : 1.39528
# batch 11 dev accuracy is : 0.68750
# batch 12 dev loss is : 1.55113
# batch 12 dev accuracy is : 0.68750
# batch 13 dev loss is : 2.03382
# batch 13 dev accuracy is : 0.68750
# batch 14 dev loss is : 0.77485
# batch 14 dev accuracy is : 0.75000
# batch 15 dev loss is : 0.83715
# batch 15 dev accuracy is : 0.93750
# batch 16 dev loss is : 1.12580
# batch 16 dev accuracy is : 0.75000
# batch 17 dev loss is : 3.08207
# batch 17 dev accuracy is : 0.62500
# batch 18 dev loss is : 2.93182
# batch 18 dev accuracy is : 0.62500
# batch 19 dev loss is : 2.54659
# batch 19 dev accuracy is : 0.81250
# batch 20 dev loss is : 1.86715
# batch 20 dev accuracy is : 0.75000
# batch 21 dev loss is : 2.27634
# batch 21 dev accuracy is : 0.68750
# batch 22 dev loss is : 1.58349
# batch 22 dev accuracy is : 0.81250
# batch 23 dev loss is : 0.40821
# batch 23 dev accuracy is : 0.75000
# batch 24 dev loss is : 0.99670
# batch 24 dev accuracy is : 0.81250
# batch 25 dev loss is : 1.34805
# batch 25 dev accuracy is : 0.75000
# batch 26 dev loss is : 1.85375
# batch 26 dev accuracy is : 0.68750
# batch 27 dev loss is : 1.51317
# batch 27 dev accuracy is : 0.68750
# Average validation loss is 1.44622 at the end of epoch 199
# Average validation accuracy is 0.72511 at the end of epoch 199

# %%
model = MyEnsemble(modelA, modelB, modelC)
model = nn.DataParallel(model, device_ids=gpu_ids)
model.to(device)
checkpoint = torch.load('/home/aidana_massalimova/classifier/agnostic/model1_upd.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
model.eval()
# Out:
# DataParallel(
#   (module): MyEnsemble(
#     (modelA): DataParallel(
#       (module): ResNet18(
#         (resnet18): ResNet(
#           (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (layer1): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer2): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer3): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer4): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc): Identity()
#         )
#       )
#     )
#     (modelB): DataParallel(
#       (module): ResNet18(
#         (resnet18): ResNet(
#           (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (layer1): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer2): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer3): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer4): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc): Identity()
#         )
#       )
#     )
#     (modelC): DataParallel(
#       (module): ResNet18(
#         (resnet18): ResNet(
#           (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (layer1): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer2): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer3): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer4): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc): Identity()
#         )
#       )
#     )
#     (classifier): Linear(in_features=1536, out_features=3, bias=True)
#   )
# )

# %%
ground_truths=[]
predictions=[]
for it, test_data in enumerate(test_loader):
    with torch.no_grad():
        t1w,FA, MD, labels = Variable(test_data['t1w']).to(device),Variable(test_data['FA']).to(device),Variable(test_data['MD']).to(device), Variable(test_data['label']).to(device) 
        integer_encoded = labels.data.cpu().numpy()
        ground_truth = Variable(torch.from_numpy(integer_encoded)).long()
        for el in ground_truth.numpy():
            ground_truths.append(el)

    test_output = model(t1w,FA,MD)
    test_prob_predict = F.softmax(test_output, dim=1)
    _, predict = test_prob_predict.topk(1)
    predict=torch.transpose(predict, 0,1)
    predict2=predict.cpu().numpy()
    for el2 in predict2:
        for el3 in el2:
            predictions.append(el3)

# %%
from sklearn.metrics import confusion_matrix,plot_confusion_matrix
print(confusion_matrix(ground_truths, predictions))
# Out:
# [[97  0  3]
#  [ 1 82 20]
#  [ 9  8 84]]

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(ground_truths, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.78      0.68       122
#            1       0.96      0.87      0.91       122
#            2       0.72      0.57      0.64       124
#
#     accuracy                           0.74       368
#    macro avg       0.76      0.74      0.74       368
# weighted avg       0.76      0.74      0.74       368

# %%
checkpoint['epoch']
# Out:
# 24
