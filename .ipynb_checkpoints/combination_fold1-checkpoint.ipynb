# %%
import sys
import torch
import torch.nn as nn
from torch import cuda
from torch.autograd import Variable
from torch.utils.data import DataLoader,Dataset

import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils
from PIL import Image

import torch.nn.functional as F

import matplotlib.pyplot as plt
import numpy as np
import random
import torch.optim as optim 

import nibabel as nib
import os
from skimage.transform import resize 
import random
import torch.utils.model_zoo as model_zoo
import torch.nn as nn
import math

# %%
class AD_2DSlicesData(Dataset):
    """labeled Faces in the Wild dataset."""
    
    def __init__(self, root_dir_1, root_dir_2, root_dir_3, data_file, transform=None, slice = slice):
        """
        Args:
            root_dir (string): Directory of all the images.
            data_file (string): File name of the train/test split file.
            transform (callable, optional): Optional transform to be applied on a sample.
            data_augmentation (boolean): Optional data augmentation.
        """
        self.root_dir_1 = root_dir_1
        self.root_dir_2 = root_dir_2
        self.root_dir_3 = root_dir_3
        self.data_file = data_file
        self.transform = transform
    
    def __len__(self):
        return sum(1 for line in open(self.data_file))
    
    def __getitem__(self, idx):
        df = open(self.data_file)
        lines = df.readlines()
        lst = lines[idx].split()
        img_name_1 = lst[0]
        img_name_2 = lst[1]
        img_name_3 = lst[2]

        img_label = lst[3]
        image_path1 = os.path.join(self.root_dir_1, img_name_1)
        image_path2 = os.path.join(self.root_dir_2, img_name_2)
        image_path3 = os.path.join(self.root_dir_3, img_name_3)
        image1 = Image.open(image_path1)
        image2 = Image.open(image_path2)
        image3 = Image.open(image_path3)

        if img_label == 'Normal':
            label = 0
        elif img_label == 'AD':
            label = 2
           
        elif img_label == 'MCI':
            label = 1
      #  elif img_label=='Demented':
           # label = 3

    
        #image = Image.fromarray(image.astype(np.uint8), 'RGB')
        if self.transform:
            image1 = self.transform(image1)
            image2 = self.transform(image2)
            image3 = self.transform(image3)

        sample = {'t1w': image3,'FA':image1, 'MD':image2, 'label': label}
        
        return sample

# %%
# Path configuration
TRAINING_PATH = '/home/aidana_massalimova/classifier/Union/train_fold1.txt'
TESTING_PATH = '/home/aidana_massalimova/classifier/Union/test_fold1.txt'
IMG_PATH_1 = '/home/aidana_massalimova/classifier/Union/fold1/train/FA'
IMG_PATH_2 = '/home/aidana_massalimova/classifier/Union/fold1/train/MD'
IMG_PATH_3 = '/home/aidana_massalimova/classifier/Union/fold1/train/T1w'

IMG_PATH_4 = '/home/aidana_massalimova/classifier/Union/fold1/test/FA'
IMG_PATH_5 = '/home/aidana_massalimova/classifier/Union/fold1/test/MD'
IMG_PATH_6 = '/home/aidana_massalimova/classifier/Union/fold1/test/T1w'


batch_size=16
epochs=200
lr = 1e-3


transforms_train = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
])

transforms_test = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
])
dset_train = AD_2DSlicesData(IMG_PATH_1, IMG_PATH_2,IMG_PATH_3,TRAINING_PATH, transforms_train)
dset_test = AD_2DSlicesData(IMG_PATH_4, IMG_PATH_5,IMG_PATH_6, TESTING_PATH, transforms_test)


# Use argument load to distinguish training and testing
train_loader = DataLoader(dset_train,
                          batch_size = batch_size,
                          shuffle = True,
                          num_workers = 4,
                          drop_last = True
                         )
test_loader = DataLoader(dset_test,
                         batch_size = batch_size,
                         shuffle = False,
                         num_workers = 4,
                         drop_last=True
                         )

# %%
class ResNet18(nn.Module):

    def __init__(self, out_size):
        super(ResNet18, self).__init__()
        self.resnet18 = torchvision.models.resnet18(pretrained=True)
        num_ftrs = self.resnet18.fc.in_features
        self.resnet18.fc = nn.Sequential(
            nn.Linear(num_ftrs, out_size)
        )

    def forward(self, x):
        x = self.resnet18(x)
        return x
    
class MyEnsemble(nn.Module):
    def __init__(self, modelA, modelB,modelC, nb_classes=3):
        super(MyEnsemble, self).__init__()
        self.modelA = modelA
        self.modelB = modelB
        self.modelC = modelC
        # Remove last linear layer
        self.modelA.module.resnet18.fc = nn.Identity()
        self.modelB.module.resnet18.fc = nn.Identity()
        self.modelC.module.resnet18.fc = nn.Identity()
        # Create new classifier
        self.classifier = nn.Linear(512+512+512, nb_classes)
        
    def forward(self, x1,x2,x3):
        x1 = self.modelA(x1) 
        x2 = self.modelB(x2)
        x3 = self.modelC(x3)
        x = torch.cat((x1, x2, x3), dim=1)   
        x = self.classifier(F.relu(x))
        return x

# Train your separate models
                                                

modelA = ResNet18(out_size=3)
modelB = ResNet18(out_size=3)
modelC = ResNet18(out_size=3)


optimizerA = eval("optim.Adam")(modelA.parameters(), 1e-4)      
optimizerB = eval("optim.Adam")(modelB.parameters(), 1e-4)
optimizerC = eval("optim.Adam")(modelC.parameters(), 1e-4)      

# Freeze these models
for param in modelA.parameters():
    param.requires_grad = False

for param in modelB.parameters():
    param.requires_grad = False

    
for param in modelC.parameters():
    param.requires_grad = False
    
gpu_ids=[11]
cuda='cuda:'+str(gpu_ids[0]) 
device=torch.device(cuda)
#cuda='cuda:0'
modelA = nn.DataParallel(modelA, device_ids=gpu_ids)
modelB = nn.DataParallel(modelB, device_ids=gpu_ids)
modelC = nn.DataParallel(modelC, device_ids=gpu_ids)


modelA.to(device)    
modelB.to(device)    
modelC.to(device)    

checkpointA = torch.load('/home/aidana_massalimova/classifier/t1w_only/model1_upd.pt')
modelA.load_state_dict(checkpointA['model_state_dict'])
optimizerA.load_state_dict(checkpointA['optimizer_state_dict'])

checkpointB = torch.load('/home/aidana_massalimova/classifier/FA_only/model1_upd.pt')
modelB.load_state_dict(checkpointB['model_state_dict'])
optimizerB.load_state_dict(checkpointB['optimizer_state_dict'])

checkpointC = torch.load('/home/aidana_massalimova/classifier/MD_only/model1_upd.pt')
modelC.load_state_dict(checkpointC['model_state_dict'])
optimizerC.load_state_dict(checkpointC['optimizer_state_dict'])
                
# Create ensemble model
model = MyEnsemble(modelA, modelB, modelC)
model = nn.DataParallel(model, device_ids=gpu_ids)
model.to(device)
# Out:
# DataParallel(
#   (module): MyEnsemble(
#     (modelA): DataParallel(
#       (module): ResNet18(
#         (resnet18): ResNet(
#           (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (layer1): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer2): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer3): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer4): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc): Identity()
#         )
#       )
#     )
#     (modelB): DataParallel(
#       (module): ResNet18(
#         (resnet18): ResNet(
#           (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (layer1): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer2): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer3): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer4): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc): Identity()
#         )
#       )
#     )
#     (modelC): DataParallel(
#       (module): ResNet18(
#         (resnet18): ResNet(
#           (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (layer1): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer2): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer3): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer4): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc): Identity()
#         )
#       )
#     )
#     (classifier): Linear(in_features=1536, out_features=3, bias=True)
#   )
# )

# %%
# Training process
criterion = torch.nn.CrossEntropyLoss()
optimizer = eval("optim.Adam")(model.parameters(), lr)
last_dev_avg_loss = float("inf")
best_accuracy = float("-inf")
# main training loop
best_accuracy=0
for epoch_i in range(epochs):
    print("At {0}-th epoch.".format(epoch_i))
    train_loss = 0.0
    correct_cnt = 0.0
    model.train()
    for it, train_data in enumerate(train_loader):
        t1w,FA,MD, labels = Variable(train_data['t1w']).to(device), Variable(train_data['FA']).to(device),Variable(train_data['MD']).to(device),Variable(train_data['label']).to(device) 

        integer_encoded = labels.data.cpu().numpy()
        ground_truth = Variable(torch.from_numpy(integer_encoded)).long().to(device)
        train_output = model(t1w,FA,MD)
        train_prob_predict = F.softmax(train_output, dim=1)
        _, predict = train_prob_predict.topk(1)
        loss = criterion(train_output, ground_truth)

        train_loss += loss
        correct_this_batch = (predict.squeeze(1) == ground_truth).sum()
        correct_cnt += correct_this_batch
        accuracy = float(correct_this_batch) / len(ground_truth)
        print("batch {0} training loss is : {1:.5f}".format(it, loss.data))
        print("batch {0} training accuracy is : {1:.5f}".format(it, accuracy))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    train_avg_loss = train_loss / (len(dset_train) / batch_size)
    train_avg_acu = float(correct_cnt) / len(dset_train)
    print("Average training loss is {0:.5f} at the end of epoch {1}".format(train_avg_loss.data, epoch_i))
    print("Average training accuracy is {0:.5f} at the end of epoch {1}".format(train_avg_acu, epoch_i))
    

    # validation -- this is a crude esitmation because there might be some paddings at the end
    dev_loss = 0.0
    correct_cnt = 0.0
    model.eval()
    for it, test_data in enumerate(test_loader):
        with torch.no_grad():
            t1w,FA,MD, labels = Variable(test_data['t1w']).to(device),Variable(test_data['FA']).to(device),Variable(test_data['MD']).to(device), Variable(test_data['label']).to(device) 
            integer_encoded = labels.data.cpu().numpy()
            ground_truth = Variable(torch.from_numpy(integer_encoded)).long().to(device)
    
        test_output = model( t1w,FA,MD)
        test_prob_predict = F.softmax(test_output, dim=1)
        _, predict = test_prob_predict.topk(1)
        loss = criterion(test_output, ground_truth)
        dev_loss += loss
        correct_this_batch = (predict.squeeze(1) == ground_truth).sum()
        correct_cnt += (predict.squeeze(1) == ground_truth).sum()
        accuracy = float(correct_this_batch) / len(ground_truth)
        print("batch {0} dev loss is : {1:.5f}".format(it, loss.data))
        print("batch {0} dev accuracy is : {1:.5f}".format(it, accuracy))

    dev_avg_loss = dev_loss / (len(dset_test) / batch_size)
    dev_avg_acu = float(correct_cnt) / len(dset_test)
    
    print("Average validation loss is {0:.5f} at the end of epoch {1}".format(dev_avg_loss.data, epoch_i))
    print("Average validation accuracy is {0:.5f} at the end of epoch {1}".format(dev_avg_acu, epoch_i))
    if dev_avg_acu>best_accuracy:       
        torch.save({ 'epoch': epoch_i,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss}, '/home/aidana_massalimova/classifier/Union/model1_upd.pt') # official recommended

    last_dev_avg_loss = dev_avg_loss
# Out:
# At 0-th epoch.
# batch 0 training loss is : 1.04282
# batch 0 training accuracy is : 0.50000
# batch 1 training loss is : 0.68918
# batch 1 training accuracy is : 0.75000
# batch 2 training loss is : 0.31936
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.48661
# batch 3 training accuracy is : 0.68750
# batch 4 training loss is : 0.44071
# batch 4 training accuracy is : 0.75000
# batch 5 training loss is : 0.23486
# batch 5 training accuracy is : 0.93750
# batch 6 training loss is : 0.07803
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.09879
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.09058
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.18520
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.09034
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.01453
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.02792
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.09034
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.01376
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.01381
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.07818
# batch 16 training accuracy is : 0.93750
# batch 17 training loss is : 0.01439
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.01668
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.01182
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00307
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.00310
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.14443
# batch 22 training accuracy is : 0.93750
# batch 23 training loss is : 0.00753
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00498
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.01190
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.02108
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00173
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.01816
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00164
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00347
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.01446
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00426
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00532
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00111
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00131
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.03576
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00270
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00828
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00754
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00170
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.00234
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00102
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.01764
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00293
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.00138
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00566
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00366
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00279
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.01952
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.01174
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.00604
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00794
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00206
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00079
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00204
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.07822 at the end of epoch 0
# Average training accuracy is 0.96247 at the end of epoch 0
# batch 0 dev loss is : 0.51256
# batch 0 dev accuracy is : 0.81250
# batch 1 dev loss is : 0.73126
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.14798
# batch 2 dev accuracy is : 1.00000
# batch 3 dev loss is : 0.12166
# batch 3 dev accuracy is : 0.93750
# batch 4 dev loss is : 0.16907
# batch 4 dev accuracy is : 0.87500
# batch 5 dev loss is : 0.45967
# batch 5 dev accuracy is : 0.93750
# batch 6 dev loss is : 1.08900
# batch 6 dev accuracy is : 0.62500
# batch 7 dev loss is : 0.10227
# batch 7 dev accuracy is : 0.93750
# batch 8 dev loss is : 0.42278
# batch 8 dev accuracy is : 0.81250
# batch 9 dev loss is : 0.66577
# batch 9 dev accuracy is : 0.75000
# batch 10 dev loss is : 0.58137
# batch 10 dev accuracy is : 0.62500
# batch 11 dev loss is : 0.53801
# batch 11 dev accuracy is : 0.81250
# batch 12 dev loss is : 0.01895
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.09521
# batch 13 dev accuracy is : 1.00000
# Average validation loss is 0.39863 at the end of epoch 0
# Average validation accuracy is 0.82819 at the end of epoch 0
# At 1-th epoch.
# batch 0 training loss is : 0.00636
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.00060
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.00487
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.01016
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.00164
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00800
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.00459
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.00173
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00723
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.02697
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.00061
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.07324
# batch 11 training accuracy is : 0.93750
# batch 12 training loss is : 0.00635
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.03170
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00206
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00256
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00270
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00073
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00660
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.06899
# batch 19 training accuracy is : 0.93750
# batch 20 training loss is : 0.01287
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.00144
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00506
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.06036
# batch 23 training accuracy is : 0.93750
# batch 24 training loss is : 0.01392
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00526
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.00683
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00560
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.00979
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00468
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00189
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00405
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00092
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00560
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.03474
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.09491
# batch 35 training accuracy is : 0.93750
# batch 36 training loss is : 0.00084
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.01076
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00322
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00239
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00058
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.00462
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00991
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.00088
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00062
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.03592
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00442
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00109
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00642
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00292
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00049
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.01288
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00132
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00387
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00064
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00069
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.01130 at the end of epoch 1
# Average training accuracy is 0.98455 at the end of epoch 1
# batch 0 dev loss is : 0.48535
# batch 0 dev accuracy is : 0.87500
# batch 1 dev loss is : 0.78856
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.15956
# batch 2 dev accuracy is : 0.87500
# batch 3 dev loss is : 0.10573
# batch 3 dev accuracy is : 1.00000
# batch 4 dev loss is : 0.15734
# batch 4 dev accuracy is : 0.93750
# batch 5 dev loss is : 0.45467
# batch 5 dev accuracy is : 0.93750
# batch 6 dev loss is : 1.07362
# batch 6 dev accuracy is : 0.62500
# batch 7 dev loss is : 0.13734
# batch 7 dev accuracy is : 0.93750
# batch 8 dev loss is : 0.42506
# batch 8 dev accuracy is : 0.81250
# batch 9 dev loss is : 0.69926
# batch 9 dev accuracy is : 0.75000
# batch 10 dev loss is : 0.56406
# batch 10 dev accuracy is : 0.81250
# batch 11 dev loss is : 0.54363
# batch 11 dev accuracy is : 0.81250
# batch 12 dev loss is : 0.02253
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.11827
# batch 13 dev accuracy is : 0.93750
# Average validation loss is 0.40423 at the end of epoch 1
# Average validation accuracy is 0.84141 at the end of epoch 1
# At 2-th epoch.
# batch 0 training loss is : 0.00350
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.00766
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.00288
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00120
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.00391
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00587
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.01370
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.00382
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00081
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00469
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.00498
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.00367
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00561
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.00030
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00727
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00113
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00350
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00088
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00048
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00051
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00269
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.04904
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.01234
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00059
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00621
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00175
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.00429
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00179
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.03568
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.01328
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00132
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00130
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00386
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00072
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00055
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00107
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00530
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00067
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00359
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00177
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.07649
# batch 40 training accuracy is : 0.93750
# batch 41 training loss is : 0.01160
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00286
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.00117
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00049
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.00141
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00080
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00218
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00147
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00970
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00135
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.00547
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00612
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00126
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00902
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00090
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.00630 at the end of epoch 2
# Average training accuracy is 0.98786 at the end of epoch 2
# batch 0 dev loss is : 0.52910
# batch 0 dev accuracy is : 0.87500
# batch 1 dev loss is : 0.88165
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.20894
# batch 2 dev accuracy is : 0.87500
# batch 3 dev loss is : 0.05711
# batch 3 dev accuracy is : 1.00000
# batch 4 dev loss is : 0.15106
# batch 4 dev accuracy is : 0.93750
# batch 5 dev loss is : 0.52658
# batch 5 dev accuracy is : 0.93750
# batch 6 dev loss is : 1.08344
# batch 6 dev accuracy is : 0.68750
# batch 7 dev loss is : 0.18783
# batch 7 dev accuracy is : 0.87500
# batch 8 dev loss is : 0.44294
# batch 8 dev accuracy is : 0.81250
# batch 9 dev loss is : 0.63150
# batch 9 dev accuracy is : 0.75000
# batch 10 dev loss is : 0.59721
# batch 10 dev accuracy is : 0.81250
# batch 11 dev loss is : 0.47804
# batch 11 dev accuracy is : 0.81250
# batch 12 dev loss is : 0.03273
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.15864
# batch 13 dev accuracy is : 0.93750
# Average validation loss is 0.42057 at the end of epoch 2
# Average validation accuracy is 0.84141 at the end of epoch 2
# At 3-th epoch.
# batch 0 training loss is : 0.00408
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.00072
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.00147
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00505
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.00994
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00025
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.00298
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.00068
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00095
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00553
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.00260
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.00068
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00629
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.00692
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00080
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00538
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00242
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00042
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00053
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00223
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.01617
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.01781
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00043
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00092
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00137
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00166
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.00032
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00054
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.00148
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00114
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00707
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00335
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00052
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00168
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00242
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00040
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00715
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00155
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00113
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00525
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.13647
# batch 40 training accuracy is : 0.93750
# batch 41 training loss is : 0.00016
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00105
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.03018
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00055
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.00175
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00215
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00165
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00767
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.01081
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.01661
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.00101
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.01297
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00335
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00070
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.01065
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.00653 at the end of epoch 3
# Average training accuracy is 0.98786 at the end of epoch 3
# batch 0 dev loss is : 0.43567
# batch 0 dev accuracy is : 0.93750
# batch 1 dev loss is : 1.01004
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.28846
# batch 2 dev accuracy is : 0.87500
# batch 3 dev loss is : 0.03798
# batch 3 dev accuracy is : 1.00000
# batch 4 dev loss is : 0.12363
# batch 4 dev accuracy is : 0.87500
# batch 5 dev loss is : 0.60813
# batch 5 dev accuracy is : 0.93750
# batch 6 dev loss is : 1.08453
# batch 6 dev accuracy is : 0.75000
# batch 7 dev loss is : 0.33983
# batch 7 dev accuracy is : 0.87500
# batch 8 dev loss is : 0.43531
# batch 8 dev accuracy is : 0.87500
# batch 9 dev loss is : 0.76884
# batch 9 dev accuracy is : 0.81250
# batch 10 dev loss is : 0.65703
# batch 10 dev accuracy is : 0.81250
# batch 11 dev loss is : 0.55103
# batch 11 dev accuracy is : 0.81250
# batch 12 dev loss is : 0.07618
# batch 12 dev accuracy is : 0.93750
# batch 13 dev loss is : 0.25301
# batch 13 dev accuracy is : 0.87500
# Average validation loss is 0.47011 at the end of epoch 3
# Average validation accuracy is 0.84581 at the end of epoch 3
# At 4-th epoch.
# batch 0 training loss is : 0.00019
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.00171
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.01016
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00946
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.01482
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.01761
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.00952
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.00315
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00146
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00109
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.00115
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.00033
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00024
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.00096
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00234
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.01981
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00759
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00664
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00140
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00077
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00800
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.00043
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00250
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00285
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00082
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00062
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.01476
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.02160
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.00178
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00042
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00011
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00113
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00057
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00142
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00054
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00113
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00063
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00102
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00007
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00066
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.01354
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.00179
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00034
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.00062
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00069
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.01271
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.02019
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00022
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00075
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00724
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00021
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.04237
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00275
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00043
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00026
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00272
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.00491 at the end of epoch 4
# Average training accuracy is 0.98896 at the end of epoch 4
# batch 0 dev loss is : 0.45841
# batch 0 dev accuracy is : 0.81250
# batch 1 dev loss is : 0.89170
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.15350
# batch 2 dev accuracy is : 0.87500
# batch 3 dev loss is : 0.08920
# batch 3 dev accuracy is : 1.00000
# batch 4 dev loss is : 0.14320
# batch 4 dev accuracy is : 0.93750
# batch 5 dev loss is : 0.49378
# batch 5 dev accuracy is : 0.93750
# batch 6 dev loss is : 1.36437
# batch 6 dev accuracy is : 0.62500
# batch 7 dev loss is : 0.16775
# batch 7 dev accuracy is : 0.87500
# batch 8 dev loss is : 0.46177
# batch 8 dev accuracy is : 0.81250
# batch 9 dev loss is : 1.03150
# batch 9 dev accuracy is : 0.68750
# batch 10 dev loss is : 0.63362
# batch 10 dev accuracy is : 0.87500
# batch 11 dev loss is : 0.73381
# batch 11 dev accuracy is : 0.75000
# batch 12 dev loss is : 0.01866
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.13709
# batch 13 dev accuracy is : 0.93750
# Average validation loss is 0.47777 at the end of epoch 4
# Average validation accuracy is 0.82819 at the end of epoch 4
# At 5-th epoch.
# batch 0 training loss is : 0.01417
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.00350
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.00044
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00498
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.00138
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00082
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.00301
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.00119
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.01241
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.05885
# batch 9 training accuracy is : 0.93750
# batch 10 training loss is : 0.00046
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.00032
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.10150
# batch 12 training accuracy is : 0.93750
# batch 13 training loss is : 0.00378
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00074
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00402
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.01535
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00032
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00015
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00011
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00013
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.01714
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00047
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00017
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00072
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00030
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.00873
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00045
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.00053
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00028
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00066
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00276
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.01232
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00036
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00123
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00629
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00040
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00994
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00022
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00013
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00052
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.00014
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00063
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.00129
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00067
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.00687
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00313
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00033
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00138
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00070
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00416
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.00039
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00234
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00108
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00300
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00183
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.00564 at the end of epoch 5
# Average training accuracy is 0.98675 at the end of epoch 5
# batch 0 dev loss is : 0.67860
# batch 0 dev accuracy is : 0.81250
# batch 1 dev loss is : 0.86243
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.11262
# batch 2 dev accuracy is : 1.00000
# batch 3 dev loss is : 0.09789
# batch 3 dev accuracy is : 0.93750
# batch 4 dev loss is : 0.14731
# batch 4 dev accuracy is : 0.93750
# batch 5 dev loss is : 0.57252
# batch 5 dev accuracy is : 0.87500
# batch 6 dev loss is : 1.59101
# batch 6 dev accuracy is : 0.62500
# batch 7 dev loss is : 0.08856
# batch 7 dev accuracy is : 1.00000
# batch 8 dev loss is : 0.55086
# batch 8 dev accuracy is : 0.81250
# batch 9 dev loss is : 0.92305
# batch 9 dev accuracy is : 0.75000
# batch 10 dev loss is : 0.73755
# batch 10 dev accuracy is : 0.62500
# batch 11 dev loss is : 0.73091
# batch 11 dev accuracy is : 0.81250
# batch 12 dev loss is : 0.00829
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.09318
# batch 13 dev accuracy is : 0.93750
# Average validation loss is 0.50712 at the end of epoch 5
# Average validation accuracy is 0.82819 at the end of epoch 5
# At 6-th epoch.
# batch 0 training loss is : 0.00128
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.00189
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.00409
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00047
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.00082
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00608
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.00057
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.00201
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00237
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00125
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.00037
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.00306
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00910
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.00016
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00150
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00284
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00321
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00023
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.04068
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00093
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00036
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.00073
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00147
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00175
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00169
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00258
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.00018
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00016
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.00009
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00048
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00192
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00009
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00017
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00126
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00064
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.02989
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00012
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00053
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00082
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00068
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00026
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.00012
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00390
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.00101
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.01177
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.00064
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00021
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00044
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00012
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00075
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00395
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.00129
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00018
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00018
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00115
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00032
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.00273 at the end of epoch 6
# Average training accuracy is 0.98896 at the end of epoch 6
# batch 0 dev loss is : 0.66762
# batch 0 dev accuracy is : 0.75000
# batch 1 dev loss is : 0.93523
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.11850
# batch 2 dev accuracy is : 0.93750
# batch 3 dev loss is : 0.07287
# batch 3 dev accuracy is : 0.93750
# batch 4 dev loss is : 0.13005
# batch 4 dev accuracy is : 0.93750
# batch 5 dev loss is : 0.59016
# batch 5 dev accuracy is : 0.87500
# batch 6 dev loss is : 1.61684
# batch 6 dev accuracy is : 0.62500
# batch 7 dev loss is : 0.11669
# batch 7 dev accuracy is : 0.87500
# batch 8 dev loss is : 0.54977
# batch 8 dev accuracy is : 0.81250
# batch 9 dev loss is : 0.95855
# batch 9 dev accuracy is : 0.75000
# batch 10 dev loss is : 0.75137
# batch 10 dev accuracy is : 0.62500
# batch 11 dev loss is : 0.76040
# batch 11 dev accuracy is : 0.81250
# batch 12 dev loss is : 0.00864
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.11307
# batch 13 dev accuracy is : 0.93750
# Average validation loss is 0.52087 at the end of epoch 6
# Average validation accuracy is 0.81057 at the end of epoch 6
# At 7-th epoch.
# batch 0 training loss is : 0.00075
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.04786
# batch 1 training accuracy is : 0.93750
# batch 2 training loss is : 0.00086
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00084
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.01527
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00099
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.00026
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.04168
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00330
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00883
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.00028
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.01745
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00021
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.00031
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00025
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00007
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00012
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00040
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00216
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00078
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00007
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.00298
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00098
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00303
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00017
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00039
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.01572
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00042
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.10508
# batch 28 training accuracy is : 0.93750
# batch 29 training loss is : 0.02191
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00259
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00440
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00138
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00014
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00043
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00236
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00037
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00165
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00105
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00244
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00632
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.00065
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00040
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.00299
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00075
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.00462
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.02012
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00004
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.03997
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00229
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00025
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.01835
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00045
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00834
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00217
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00165
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.00741 at the end of epoch 7
# Average training accuracy is 0.98675 at the end of epoch 7
# batch 0 dev loss is : 0.73436
# batch 0 dev accuracy is : 0.81250
# batch 1 dev loss is : 0.93239
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.10173
# batch 2 dev accuracy is : 1.00000
# batch 3 dev loss is : 0.08698
# batch 3 dev accuracy is : 0.93750
# batch 4 dev loss is : 0.15301
# batch 4 dev accuracy is : 0.93750
# batch 5 dev loss is : 0.57249
# batch 5 dev accuracy is : 0.87500
# batch 6 dev loss is : 1.68421
# batch 6 dev accuracy is : 0.62500
# batch 7 dev loss is : 0.06849
# batch 7 dev accuracy is : 1.00000
# batch 8 dev loss is : 0.61295
# batch 8 dev accuracy is : 0.81250
# batch 9 dev loss is : 0.90724
# batch 9 dev accuracy is : 0.75000
# batch 10 dev loss is : 0.71662
# batch 10 dev accuracy is : 0.62500
# batch 11 dev loss is : 0.73949
# batch 11 dev accuracy is : 0.81250
# batch 12 dev loss is : 0.00519
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.08630
# batch 13 dev accuracy is : 0.93750
# Average validation loss is 0.52169 at the end of epoch 7
# Average validation accuracy is 0.82819 at the end of epoch 7
# At 8-th epoch.
# batch 0 training loss is : 0.00014
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.00572
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.00016
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00023
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.00011
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00015
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.00006
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.00006
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00064
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00011
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.00008
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.00145
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00365
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.14340
# batch 13 training accuracy is : 0.93750
# batch 14 training loss is : 0.00070
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00208
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00006
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00215
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00008
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00013
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00216
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.00014
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00025
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00024
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00009
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00077
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.00093
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00002
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.00002
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00308
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00015
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00178
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00397
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00001
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00051
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00046
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00016
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00003
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00786
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00025
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00154
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.04053
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00016
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.00066
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00009
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.01123
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00641
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00618
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00005
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00006
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00082
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.05505
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00002
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00356
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00002
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00217
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.00552 at the end of epoch 8
# Average training accuracy is 0.98786 at the end of epoch 8
# batch 0 dev loss is : 0.66432
# batch 0 dev accuracy is : 0.75000
# batch 1 dev loss is : 1.05997
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.13435
# batch 2 dev accuracy is : 0.93750
# batch 3 dev loss is : 0.06801
# batch 3 dev accuracy is : 0.93750
# batch 4 dev loss is : 0.14577
# batch 4 dev accuracy is : 0.93750
# batch 5 dev loss is : 0.60814
# batch 5 dev accuracy is : 0.93750
# batch 6 dev loss is : 1.69860
# batch 6 dev accuracy is : 0.62500
# batch 7 dev loss is : 0.13508
# batch 7 dev accuracy is : 0.87500
# ...
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00000
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.00133
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00000
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.00000
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.00000
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00000
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00000
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.00000
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.00004
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00000
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.00000
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00000
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00000
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00000
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00000
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00000
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00000
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00000
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.00000
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00000
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00000
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00000
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00000
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.00000
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00000
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.00000
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00163
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00000
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00000
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00000
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00000
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00000
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00000
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00000
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00000
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00000
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00000
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00000
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.00000
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00000
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.00000
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00000
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.00000
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00000
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00000
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00000
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00000
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00000
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.00000
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00000
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00000
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00000
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00000
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.00005 at the end of epoch 197
# Average training accuracy is 0.98896 at the end of epoch 197
# batch 0 dev loss is : 2.40366
# batch 0 dev accuracy is : 0.75000
# batch 1 dev loss is : 2.52928
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.15220
# batch 2 dev accuracy is : 0.93750
# batch 3 dev loss is : 0.23218
# batch 3 dev accuracy is : 0.93750
# batch 4 dev loss is : 0.69018
# batch 4 dev accuracy is : 0.93750
# batch 5 dev loss is : 1.44849
# batch 5 dev accuracy is : 0.93750
# batch 6 dev loss is : 6.64393
# batch 6 dev accuracy is : 0.62500
# batch 7 dev loss is : 0.40894
# batch 7 dev accuracy is : 0.93750
# batch 8 dev loss is : 2.18399
# batch 8 dev accuracy is : 0.81250
# batch 9 dev loss is : 4.74926
# batch 9 dev accuracy is : 0.75000
# batch 10 dev loss is : 2.52839
# batch 10 dev accuracy is : 0.87500
# batch 11 dev loss is : 3.98472
# batch 11 dev accuracy is : 0.81250
# batch 12 dev loss is : 0.00093
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.04838
# batch 13 dev accuracy is : 0.93750
# Average validation loss is 1.97389 at the end of epoch 197
# Average validation accuracy is 0.83700 at the end of epoch 197
# At 198-th epoch.
# batch 0 training loss is : 0.00000
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.00000
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.00000
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00000
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.00000
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00000
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 1.49641
# batch 6 training accuracy is : 0.93750
# batch 7 training loss is : 0.00131
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00000
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00000
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.00000
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.00000
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00000
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.00000
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00009
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00000
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00000
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00000
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00000
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00000
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00000
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.00000
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00000
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00000
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00000
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00000
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.00313
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00000
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.00000
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00000
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00000
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00000
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00000
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00000
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00000
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00000
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00000
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00000
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00000
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00000
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00000
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.00000
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.00000
# batch 42 training accuracy is : 1.00000
# batch 43 training loss is : 0.00000
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00000
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.00000
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00000
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00000
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00000
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00000
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00000
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.00000
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.13685
# batch 52 training accuracy is : 0.93750
# batch 53 training loss is : 0.00000
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00000
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00000
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.02892 at the end of epoch 198
# Average training accuracy is 0.98675 at the end of epoch 198
# batch 0 dev loss is : 3.90540
# batch 0 dev accuracy is : 0.81250
# batch 1 dev loss is : 2.56029
# batch 1 dev accuracy is : 0.62500
# batch 2 dev loss is : 0.26969
# batch 2 dev accuracy is : 0.93750
# batch 3 dev loss is : 0.17283
# batch 3 dev accuracy is : 0.93750
# batch 4 dev loss is : 0.92225
# batch 4 dev accuracy is : 0.93750
# batch 5 dev loss is : 1.64757
# batch 5 dev accuracy is : 0.93750
# batch 6 dev loss is : 5.64176
# batch 6 dev accuracy is : 0.68750
# batch 7 dev loss is : 0.59569
# batch 7 dev accuracy is : 0.87500
# batch 8 dev loss is : 2.19687
# batch 8 dev accuracy is : 0.81250
# batch 9 dev loss is : 2.76070
# batch 9 dev accuracy is : 0.81250
# batch 10 dev loss is : 2.70613
# batch 10 dev accuracy is : 0.81250
# batch 11 dev loss is : 2.70121
# batch 11 dev accuracy is : 0.81250
# batch 12 dev loss is : 0.01017
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.54071
# batch 13 dev accuracy is : 0.87500
# Average validation loss is 1.87709 at the end of epoch 198
# Average validation accuracy is 0.83700 at the end of epoch 198
# At 199-th epoch.
# batch 0 training loss is : 0.00000
# batch 0 training accuracy is : 1.00000
# batch 1 training loss is : 0.00000
# batch 1 training accuracy is : 1.00000
# batch 2 training loss is : 0.00000
# batch 2 training accuracy is : 1.00000
# batch 3 training loss is : 0.00000
# batch 3 training accuracy is : 1.00000
# batch 4 training loss is : 0.00000
# batch 4 training accuracy is : 1.00000
# batch 5 training loss is : 0.00000
# batch 5 training accuracy is : 1.00000
# batch 6 training loss is : 0.00000
# batch 6 training accuracy is : 1.00000
# batch 7 training loss is : 0.00000
# batch 7 training accuracy is : 1.00000
# batch 8 training loss is : 0.00000
# batch 8 training accuracy is : 1.00000
# batch 9 training loss is : 0.00000
# batch 9 training accuracy is : 1.00000
# batch 10 training loss is : 0.02274
# batch 10 training accuracy is : 1.00000
# batch 11 training loss is : 0.00006
# batch 11 training accuracy is : 1.00000
# batch 12 training loss is : 0.00001
# batch 12 training accuracy is : 1.00000
# batch 13 training loss is : 0.00000
# batch 13 training accuracy is : 1.00000
# batch 14 training loss is : 0.00000
# batch 14 training accuracy is : 1.00000
# batch 15 training loss is : 0.00000
# batch 15 training accuracy is : 1.00000
# batch 16 training loss is : 0.00000
# batch 16 training accuracy is : 1.00000
# batch 17 training loss is : 0.00000
# batch 17 training accuracy is : 1.00000
# batch 18 training loss is : 0.00000
# batch 18 training accuracy is : 1.00000
# batch 19 training loss is : 0.00000
# batch 19 training accuracy is : 1.00000
# batch 20 training loss is : 0.00000
# batch 20 training accuracy is : 1.00000
# batch 21 training loss is : 0.00000
# batch 21 training accuracy is : 1.00000
# batch 22 training loss is : 0.00007
# batch 22 training accuracy is : 1.00000
# batch 23 training loss is : 0.00000
# batch 23 training accuracy is : 1.00000
# batch 24 training loss is : 0.00000
# batch 24 training accuracy is : 1.00000
# batch 25 training loss is : 0.00000
# batch 25 training accuracy is : 1.00000
# batch 26 training loss is : 0.00000
# batch 26 training accuracy is : 1.00000
# batch 27 training loss is : 0.00000
# batch 27 training accuracy is : 1.00000
# batch 28 training loss is : 0.02314
# batch 28 training accuracy is : 1.00000
# batch 29 training loss is : 0.00000
# batch 29 training accuracy is : 1.00000
# batch 30 training loss is : 0.00000
# batch 30 training accuracy is : 1.00000
# batch 31 training loss is : 0.00000
# batch 31 training accuracy is : 1.00000
# batch 32 training loss is : 0.00000
# batch 32 training accuracy is : 1.00000
# batch 33 training loss is : 0.00000
# batch 33 training accuracy is : 1.00000
# batch 34 training loss is : 0.00000
# batch 34 training accuracy is : 1.00000
# batch 35 training loss is : 0.00001
# batch 35 training accuracy is : 1.00000
# batch 36 training loss is : 0.00000
# batch 36 training accuracy is : 1.00000
# batch 37 training loss is : 0.00000
# batch 37 training accuracy is : 1.00000
# batch 38 training loss is : 0.00000
# batch 38 training accuracy is : 1.00000
# batch 39 training loss is : 0.00305
# batch 39 training accuracy is : 1.00000
# batch 40 training loss is : 0.00000
# batch 40 training accuracy is : 1.00000
# batch 41 training loss is : 0.00000
# batch 41 training accuracy is : 1.00000
# batch 42 training loss is : 0.05350
# batch 42 training accuracy is : 0.93750
# batch 43 training loss is : 0.00001
# batch 43 training accuracy is : 1.00000
# batch 44 training loss is : 0.00000
# batch 44 training accuracy is : 1.00000
# batch 45 training loss is : 0.00000
# batch 45 training accuracy is : 1.00000
# batch 46 training loss is : 0.00000
# batch 46 training accuracy is : 1.00000
# batch 47 training loss is : 0.00000
# batch 47 training accuracy is : 1.00000
# batch 48 training loss is : 0.00000
# batch 48 training accuracy is : 1.00000
# batch 49 training loss is : 0.00000
# batch 49 training accuracy is : 1.00000
# batch 50 training loss is : 0.00000
# batch 50 training accuracy is : 1.00000
# batch 51 training loss is : 0.00000
# batch 51 training accuracy is : 1.00000
# batch 52 training loss is : 0.00000
# batch 52 training accuracy is : 1.00000
# batch 53 training loss is : 0.00000
# batch 53 training accuracy is : 1.00000
# batch 54 training loss is : 0.00000
# batch 54 training accuracy is : 1.00000
# batch 55 training loss is : 0.00000
# batch 55 training accuracy is : 1.00000
# Average training loss is 0.00181 at the end of epoch 199
# Average training accuracy is 0.98786 at the end of epoch 199
# batch 0 dev loss is : 5.55232
# batch 0 dev accuracy is : 0.81250
# batch 1 dev loss is : 2.77347
# batch 1 dev accuracy is : 0.81250
# batch 2 dev loss is : 0.34823
# batch 2 dev accuracy is : 0.87500
# batch 3 dev loss is : 0.97209
# batch 3 dev accuracy is : 0.87500
# batch 4 dev loss is : 1.37246
# batch 4 dev accuracy is : 0.87500
# batch 5 dev loss is : 2.00716
# batch 5 dev accuracy is : 0.75000
# batch 6 dev loss is : 7.07188
# batch 6 dev accuracy is : 0.68750
# batch 7 dev loss is : 0.01617
# batch 7 dev accuracy is : 1.00000
# batch 8 dev loss is : 3.05863
# batch 8 dev accuracy is : 0.75000
# batch 9 dev loss is : 3.10588
# batch 9 dev accuracy is : 0.81250
# batch 10 dev loss is : 3.19694
# batch 10 dev accuracy is : 0.75000
# batch 11 dev loss is : 3.35519
# batch 11 dev accuracy is : 0.87500
# batch 12 dev loss is : 0.00001
# batch 12 dev accuracy is : 1.00000
# batch 13 dev loss is : 0.71913
# batch 13 dev accuracy is : 0.93750
# Average validation loss is 2.36473 at the end of epoch 199
# Average validation accuracy is 0.83260 at the end of epoch 199

# %%
model = MyEnsemble(modelA, modelB, modelC)
model = nn.DataParallel(model, device_ids=gpu_ids)
model.to(device)
checkpoint = torch.load('/home/aidana_massalimova/classifier/Union/model1_upd.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
model.eval()
# Out:
# DataParallel(
#   (module): MyEnsemble(
#     (modelA): DataParallel(
#       (module): ResNet18(
#         (resnet18): ResNet(
#           (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (layer1): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer2): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer3): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer4): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc): Identity()
#         )
#       )
#     )
#     (modelB): DataParallel(
#       (module): ResNet18(
#         (resnet18): ResNet(
#           (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (layer1): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer2): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer3): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer4): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc): Identity()
#         )
#       )
#     )
#     (modelC): DataParallel(
#       (module): ResNet18(
#         (resnet18): ResNet(
#           (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (layer1): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer2): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer3): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (layer4): Sequential(
#             (0): BasicBlock(
#               (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (downsample): Sequential(
#                 (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#                 (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (1): BasicBlock(
#               (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (relu): ReLU(inplace=True)
#               (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#           (fc): Identity()
#         )
#       )
#     )
#     (classifier): Linear(in_features=1536, out_features=3, bias=True)
#   )
# )

# %%
ground_truths=[]
predictions=[]
for it, test_data in enumerate(test_loader):
    with torch.no_grad():
        t1w,FA, MD, labels = Variable(test_data['t1w']).to(device),Variable(test_data['FA']).to(device),Variable(test_data['MD']).to(device), Variable(test_data['label']).to(device) 
        integer_encoded = labels.data.cpu().numpy()
        ground_truth = Variable(torch.from_numpy(integer_encoded)).long()
        for el in ground_truth.numpy():
            ground_truths.append(el)

    test_output = model(t1w,FA,MD)
    test_prob_predict = F.softmax(test_output, dim=1)
    _, predict = test_prob_predict.topk(1)
    predict=torch.transpose(predict, 0,1)
    predict2=predict.cpu().numpy()
    for el2 in predict2:
        for el3 in el2:
            predictions.append(el3)

# %%
from sklearn.metrics import confusion_matrix,plot_confusion_matrix
print(confusion_matrix(ground_truths, predictions))
# Out:
# [[70  1  4]
#  [ 4 70  0]
#  [19  7 49]]

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(ground_truths, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.93      0.83        75
#            1       0.90      0.95      0.92        74
#            2       0.92      0.65      0.77        75
#
#     accuracy                           0.84       224
#    macro avg       0.86      0.84      0.84       224
# weighted avg       0.86      0.84      0.84       224

# %%
checkpoint['epoch']
# Out:
# 199
